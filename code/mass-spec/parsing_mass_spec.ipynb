# %% [markdown]
# # Processing data from Mass-spectrometry experiments

# %%
import numpy as np
import pandas as pd

from copy import deepcopy

import matplotlib.pyplot as plt

import regseq2

regseq2.viz.matplotlib_style()

# %% [markdown]
# ## Parse individual files

# %% [markdown]
# In this data we are looking for enrichment of transcription factors bound to the DNA oligos compared to control sequences. We first normalize the abundance of all proteins within a sample, and then compare the relative abundance of each protein in a sample compared to control.

# %%
def parse_mass_spec(file, sample_dict, gc_dict):
    # some files are csv, some are excel
    if '.csv' in file:
        df = pd.read_csv(file)
    elif '.xlsx' in file:
        df = pd.read_excel(file)

    # get date of experiment
    date = file.split('/')[5].split('_')[0]

    # Get column headers
    cols = [x for x in df.columns if np.any([y == x[:3] for y in sample_dict.keys()])]
    df = deepcopy(df)

    # normalize each sample
    for col in cols:
        df[col] = df[col] / np.sum(df[col])
    
    # reshape dataframe
    df_parsed = pd.melt(df, id_vars=['Sum PEP Score', '# Peptides', 'Gene Symbol'], value_vars=cols, var_name='sample', value_name='abundance')
    
    # add condition and sample name
    sample = []
    gc = []
    for s in df_parsed['sample'].values:
        sample.append(sample_dict[s[:3]])
        gc.append(gc_dict[s[3:]])
    df_parsed['sample'] = sample
    df_parsed['condition'] = gc

    # split by conditions and compute enrichment
    out_df_list = []
    control_list = []
    for gc, gdf in df_parsed.groupby('condition'):
        gdf = pd.pivot(gdf, index=['Sum PEP Score', '# Peptides', 'Gene Symbol', 'condition'], columns='sample', values='abundance').reset_index()
        
        control_cols = [col for col in gdf.columns[4:] if 'Control' in col]
        filtered_cols = [col for col in gdf.columns[4:] if 'Control' not in col]
        
        for control in control_cols:
            _df = deepcopy(gdf)
            _df = _df[_df[control] > 0]
            for col in filtered_cols:
                _df[col] = _df[col] / _df[control]
                
            _df.drop(control_cols, axis=1, inplace=True)
            _df['Control'] = [key for key, val in sample_dict.items() if val == control][0]
            _df['date'] = date
            
            out_df_list.append(_df.dropna(subset='Gene Symbol').fillna(0))
            control_list.append((_df['Control'].values[0], _df['condition'].values[0]))
    return out_df_list, control_list

# %% [markdown]
# Now we go through each experiment, and compute enrichments. Then, all experiments get concatenated together for easier evaluation later. In each experiment, the samples are named by the DNA oligo used and the condition the cells used to make the lysate are grown in .

# %%
df_list = []
df = pd.read_csv("../../../data/mass-spec/20240905_salt_stat-phase/HJ_20240905_OTE_AurTS25_TMTpro_1.csv")

sample_dict = {
    "058": "Control",
    "208": "yjbJ",
    "210": "yadE",
    "212": "yadI",
    "214": "ybaY",
    "216": "yagB",
    "218": "yqjE"
}

gc_dict = {
    "S": 'stationary',
    "N": 'salt'
}
out_df_list, control_list = parse_mass_spec("../../../data/mass-spec/20240905_salt_stat-phase/HJ_20240905_OTE_AurTS25_TMTpro_1.csv", sample_dict, gc_dict)
print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('058', 'salt'), ('058', 'stationary')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition      yadE      yadI  \
# 1               0.667           1        norV      salt  1.337115  0.603475
# 2               0.669           1        bamB      salt  0.954172  1.028334
# 4               0.674           1        uvrC      salt  1.043993  1.252748
# 5               0.676           1        paaB      salt  1.161389  1.474776
# 6               0.687           1        ampH      salt  1.198578  1.047317
#
# sample      yagB      ybaY      yjbJ      yqjE Control      date
# 1       1.198823  1.977088  0.895357  0.743588     058  20240905
# 2       0.349491  0.912143  0.874587  0.681428     058  20240905
# 4       1.630782  1.308406  1.144466  1.007915     058  20240905
# 5       2.134713  2.088479  1.208958  1.730728     058  20240905
# 6       1.627733  1.260605  1.373734  0.880463     058  20240905

# %%
sample_dict = {
    "058": "Control",
    "208": "yjbJ",
    "210": "yadE",
    "212": "yadI",
    "214": "ybaY",
    "216": "yagB",
    "218": "yqjE"
}

gc_dict = {
    "SA": 'stationary, 37C',
    "NA": 'salt, 37C'
}

out_df_list, control_list = parse_mass_spec("../../../data/mass-spec/20240905_salt_stat-phase/HJ_20240905_OTE_AurTS25_TMTpro_2.csv", sample_dict, gc_dict)
print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('058', 'salt, 37C'), ('058', 'stationary, 37C')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition      yadE      yadI  \
# 0               0.857           1        dkgA  salt, 37C  0.647869  0.806747
# 1               0.862           1        yfcS  salt, 37C  1.314038  1.304962
# 2               0.885           1       coaBC  salt, 37C  0.911062  1.123397
# 3               0.885           1        fucU  salt, 37C  1.148481  1.318150
# 4               0.888           1        yeeJ  salt, 37C  1.350603  1.625477
#
# sample      yagB      ybaY      yjbJ      yqjE Control      date
# 0       0.459999  0.826681  0.452815  0.491718     058  20240905
# 1       0.861778  1.602645  0.771200  0.692148     058  20240905
# 2       1.015582  1.719515  0.756684  0.849036     058  20240905
# 3       0.929154  1.226961  0.901481  1.075390     058  20240905
# 4       0.705539  1.266195  0.917889  0.680888     058  20240905

# %%
df = pd.read_excel("../../../data/mass-spec/20241031/HJ_20241031_OTE_AurTS25_sc90min_1.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '496C',
#        '496G', '241G', '058C', '058G', '839G', '837G', '835G', '496CH', '496H',
#        '241H', '058CH', '058H', '839H', '837H', '835H',
#        'Found in Sample: [S225] F17: 126, Sample',
#        'Found in Sample: [S227] F17: 127C, Sample',
#        'Found in Sample: [S226] F17: 127N, Sample',
#        'Found in Sample: [S229] F17: 128C, Sample',
#        'Found in Sample: [S228] F17: 128N, Sample',
#        'Found in Sample: [S231] F17: 129C, Sample',
#        'Found in Sample: [S230] F17: 129N, Sample',
#        'Found in Sample: [S233] F17: 130C, Sample',
#        'Found in Sample: [S232] F17: 130N, Sample',
#        'Found in Sample: [S235] F17: 131C, Sample',
#        'Found in Sample: [S234] F17: 131N, Sample',
#        'Found in Sample: [S237] F17: 132C, Sample',
#        'Found in Sample: [S236] F17: 132N, Sample',
#        'Found in Sample: [S239] F17: 133C, Sample',
#        'Found in Sample: [S238] F17: 133N, Sample',
#        'Found in Sample: [S241] F17: 134C, Sample',
#        'Found in Sample: [S240] F17: 134N, Sample',
#        'Found in Sample: [S242] F17: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "058": "Control",
    "496": "mglB_1",
    "241": "araB_2",
    "839": "Control_long",
    "837": "Control_medium",
    "835": "Control_short",
}

gc_dict = {
    "C": 'cAMP, 4C',
    "CH": 'cAMP, 37C',
    "H": 'glucose, 37C',
    "G": 'glucose, 4C'
}

out_df_list, control_list = parse_mass_spec("../../../data/mass-spec/20241031/HJ_20241031_OTE_AurTS25_sc90min_1.xlsx", sample_dict, gc_dict)
print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('058', 'cAMP, 37C'), ('058', 'cAMP, 4C'), ('058', 'glucose, 37C'), ('839', 'glucose, 37C'), ('837', 'glucose, 37C'), ('835', 'glucose, 37C'), ('058', 'glucose, 4C'), ('839', 'glucose, 4C'), ('837', 'glucose, 4C'), ('835', 'glucose, 4C')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition    mglB_1 Control  \
# 0               0.945           1        yihL  cAMP, 37C  0.886620     058
# 1               0.982           1         gph  cAMP, 37C  1.097478     058
# 2               0.992           1        intA  cAMP, 37C  1.252113     058
# 3               1.005           1        manA  cAMP, 37C  1.112218     058
# 4               1.016           1        recC  cAMP, 37C  1.146480     058
#
# sample      date
# 0       20241031
# 1       20241031
# 2       20241031
# 3       20241031
# 4       20241031

# %%
df = pd.read_excel("../../../data/mass-spec/20241031/HJ_20241031_OTE_AurTS25_sc90min_2.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '058N',
#        '208N', '216N', '058S', '208S', '216S', '054G', '058G', '058NA',
#        '208NA', '216NA', '058SA', '208SA', '216SA', '054GA', '058GA',
#        'Found in Sample: [S243] F18: 126, Sample',
#        'Found in Sample: [S245] F18: 127C, Sample',
#        'Found in Sample: [S244] F18: 127N, Sample',
#        'Found in Sample: [S247] F18: 128C, Sample',
#        'Found in Sample: [S246] F18: 128N, Sample',
#        'Found in Sample: [S249] F18: 129C, Sample',
#        'Found in Sample: [S248] F18: 129N, Sample',
#        'Found in Sample: [S251] F18: 130C, Sample',
#        'Found in Sample: [S250] F18: 130N, Sample',
#        'Found in Sample: [S253] F18: 131C, Sample',
#        'Found in Sample: [S252] F18: 131N, Sample',
#        'Found in Sample: [S255] F18: 132C, Sample',
#        'Found in Sample: [S254] F18: 132N, Sample',
#        'Found in Sample: [S257] F18: 133C, Sample',
#        'Found in Sample: [S256] F18: 133N, Sample',
#        'Found in Sample: [S259] F18: 134C, Sample',
#        'Found in Sample: [S258] F18: 134N, Sample',
#        'Found in Sample: [S260] F18: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "058": "Control",
    "054": "lacI_Oid",
    "208": "yjbJ",
    "216": "yagB",
}

gc_dict = {
    'S': 'stationary',
    'N': 'salt',
    'G': 'glucose',
    'SA': 'stationary, 37C',
    'NA': 'salt, 37C',
    'GA': 'glucose, 37C'
}

file = "../../../data/mass-spec/20241031/HJ_20241031_OTE_AurTS25_sc90min_2.xlsx"
out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)
print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('058', 'glucose'), ('058', 'glucose, 37C'), ('058', 'salt'), ('058', 'salt, 37C'), ('058', 'stationary'), ('058', 'stationary, 37C')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition  lacI_Oid Control  \
# 1               0.977           1        corC   glucose  1.800420     058
# 2               1.001           1        leuB   glucose  0.746314     058
# 3               1.032           1        gloA   glucose  0.964412     058
# 4               1.052           1         mdh   glucose  0.811423     058
# 5               1.056           1        uspE   glucose  1.043356     058
#
# sample      date
# 1       20241031
# 2       20241031
# 3       20241031
# 4       20241031
# 5       20241031

# %%
sample_dict = {
    "058": "Control",
    "054": "lacI_Oid",
    "208": "yjbJ",
    "216": "yagB",
}

gc_dict = {
    'S': 'stationary, 4C',
    'N': 'salt, 4C',
    'G': 'glucose, 4C',
    'SA': 'stationary, 37C',
    'NA': 'salt, 37C',
    'GA': 'glucose, 37C'
}

file = "../../../data/mass-spec/20241105/HJ_20241031_OTE_AurTS25_sc90min_2.xlsx"
out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)
print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('058', 'glucose, 37C'), ('058', 'glucose, 4C'), ('058', 'salt, 37C'), ('058', 'salt, 4C'), ('058', 'stationary, 37C'), ('058', 'stationary, 4C')]
# sample  Sum PEP Score  # Peptides Gene Symbol     condition  lacI_Oid Control  \
# 1               0.977           1        corC  glucose, 37C  1.059888     058
# 2               1.001           1        leuB  glucose, 37C  0.849838     058
# 3               1.032           1        gloA  glucose, 37C  1.553941     058
# 4               1.052           1         mdh  glucose, 37C  1.482270     058
# 5               1.056           1        uspE  glucose, 37C  0.913251     058
#
# sample      date
# 1       20241105
# 2       20241105
# 3       20241105
# 4       20241105
# 5       20241105

# %%
df = pd.read_excel("../../../data/mass-spec/20241125/HJ_20241125_OTE_AurTS25_set1_proteins.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '208S',
#        '212S', '216S', '233S', '829S', '835S', '837S', '839S', '174S', '176S',
#        '178S', '180S', '186S', '188S', '192S', '196S',
#        'Found in Sample: [S261] F19: 126, Sample',
#        'Found in Sample: [S262] F19: 127N, Sample',
#        'Found in Sample: [S263] F19: 127C, Sample',
#        'Found in Sample: [S264] F19: 128N, Sample',
#        'Found in Sample: [S265] F19: 128C, Sample',
#        'Found in Sample: [S266] F19: 129N, Sample',
#        'Found in Sample: [S267] F19: 129C, Sample',
#        'Found in Sample: [S268] F19: 130N, Sample',
#        'Found in Sample: [S269] F19: 130C, Sample',
#        'Found in Sample: [S270] F19: 131N, Sample',
#        'Found in Sample: [S271] F19: 131C, Sample',
#        'Found in Sample: [S272] F19: 132N, Sample',
#        'Found in Sample: [S273] F19: 132C, Sample',
#        'Found in Sample: [S274] F19: 133N, Sample',
#        'Found in Sample: [S275] F19: 133C, Sample',
#        'Found in Sample: [S276] F19: 134N, Sample',
#        'Found in Sample: [S277] F19: 134C, Sample',
#        'Found in Sample: [S278] F19: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "208": "yjbJ",
    "216": "yagB",
    '212': 'yadI',
    '233': 'gyrA',
    '829': 'acrZ',
    '835': 'Control',
    '837': 'Control_2',
    '839': 'Control_3',
    '174': 'mhpRp2',
    '176': 'ygiW_1',
    '178': 'ygiW_2',
    '180': 'sohA',
    '186': 'elaB',
    '188': 'rcsBp2',
    '192': 'galEp1',
    '196': 'tisB'
}

gc_dict = {
    'S': 'stationary',
}

file = "../../../data/mass-spec/20241125/HJ_20241125_OTE_AurTS25_set1_proteins.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)
print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('835', 'stationary'), ('837', 'stationary'), ('839', 'stationary')]
# sample  Sum PEP Score  # Peptides Gene Symbol   condition      acrZ      elaB  \
# 1               0.704           1        ybhR  stationary  1.926296  1.030832
# 2               0.705           1        rplP  stationary  1.250113  0.928958
# 4               0.713           1        ydcC  stationary  1.388916  1.486436
# 6               0.728           1         fnr  stationary  1.413541  1.362518
# 7               0.744           1        adiA  stationary  0.791320  0.588088
#
# sample    galEp1      gyrA    mhpRp2    rcsBp2      sohA      tisB      yadI  \
# 1       1.023576  0.795138  1.166161  1.339130  1.122992  0.708967  1.083449
# 2       0.670643  1.229551  0.886647  0.797968  0.943984  0.841579  1.156676
# 4       0.912751  2.283700  1.165679  1.134192  1.160907  1.734329  2.817193
# 6       0.820262  1.295073  1.549374  1.078757  1.175479  1.149622  1.380262
# 7       0.990957  0.690359  0.505569  0.595225  0.720869  3.375442  0.463795
#
# sample      yagB    ygiW_1     ygiW_2      yjbJ Control      date
# 1       0.611859  1.005459  10.773220  1.440959     835  20241125
# 2       0.834637  0.794670   1.093834  1.274766     835  20241125
# 4       1.111297  1.150434   1.399658  3.429108     835  20241125
# 6       1.162002  0.998371   1.314059  1.640358     835  20241125
# 7       0.365767  0.674847   0.505204  0.588079     835  20241125

# %%
df = pd.read_excel("../../../data/mass-spec/20241125/HJ_20241125_OTE_AurTS25_set2_proteins.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '837P',
#        '975P', '977P', '979P', '981P', '983P', '985P', '837N1', '098N1',
#        '985N1', '837N2', '208N2', '214N2', '216N2', '098N2', '985N2',
#        'Found in Sample: [S279] F20: 126, Sample',
#        'Found in Sample: [S280] F20: 127N, Sample',
#        'Found in Sample: [S281] F20: 127C, Sample',
#        'Found in Sample: [S282] F20: 128N, Sample',
#        'Found in Sample: [S283] F20: 128C, Sample',
#        'Found in Sample: [S284] F20: 129N, Sample',
#        'Found in Sample: [S285] F20: 129C, Sample',
#        'Found in Sample: [S286] F20: 130N, Sample',
#        'Found in Sample: [S287] F20: 130C, Sample',
#        'Found in Sample: [S288] F20: 131N, Sample',
#        'Found in Sample: [S289] F20: 131C, Sample',
#        'Found in Sample: [S290] F20: 132N, Sample',
#        'Found in Sample: [S291] F20: 132C, Sample',
#        'Found in Sample: [S292] F20: 133N, Sample',
#        'Found in Sample: [S293] F20: 133C, Sample',
#        'Found in Sample: [S294] F20: 134N, Sample',
#        'Found in Sample: [S295] F20: 134C, Sample',
#        'Found in Sample: [S296] F20: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "975": "pheMp",
    "977": "furpb",
    '979': 'flda',
    '981': 'ihfAp',
    '983': 'ompRp3',
    '985': 'ecnb',
    '098': 'yqaE',
    '208': 'yjbJ',
    '214': 'ybaY',
    '216': 'yagB',
    '837': 'Control'
}

gc_dict = {
    'P': 'phenazine',
    'N1': 'salt',
    'N2': 'salt2'
}

file = "../../../data/mass-spec/20241125/HJ_20241125_OTE_AurTS25_set2_proteins.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'phenazine'), ('837', 'salt'), ('837', 'salt2')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition      ecnb      flda  \
# 0               0.702           1        ispH  phenazine  0.420751  1.970115
# 2               0.715           1        ynfL  phenazine  0.661186  2.360458
# 3               0.721           1        leuC  phenazine  0.677650  2.390312
# 4               0.726           1        ymfD  phenazine  1.888540  1.810439
# 6               0.736           1        argG  phenazine  0.660935  1.373187
#
# sample     furpb     ihfAp    ompRp3     pheMp Control      date
# 0       1.371717  0.443603  1.249659  1.168800     837  20241125
# 2       1.594576  0.578972  1.587964  1.718929     837  20241125
# 3       1.555270  0.642539  1.479206  1.388748     837  20241125
# 4       1.526497  1.435041  1.473193  1.331351     837  20241125
# 6       2.688696  0.657279  1.572246  0.870212     837  20241125

# %%
df = pd.read_excel("../../../data/mass-spec/20241216/HJ_20241216_OTE_AurTS25_setR.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '098S',
#        '174S', '176S', '178S', '180S', '182S', '186S', '188S', '190S', '192S',
#        '194S', '196S', '233S', '829S', '837S', '839S',
#        'Found in Sample: [S298] F22: 126, Sample',
#        'Found in Sample: [S316] F22: 127N, Sample',
#        'Found in Sample: [S317] F22: 127C, Sample',
#        'Found in Sample: [S318] F22: 128N, Sample',
#        'Found in Sample: [S319] F22: 128C, Sample',
#        'Found in Sample: [S320] F22: 129N, Sample',
#        'Found in Sample: [S321] F22: 129C, Sample',
#        'Found in Sample: [S322] F22: 130N, Sample',
#        'Found in Sample: [S323] F22: 130C, Sample',
#        'Found in Sample: [S324] F22: 131N, Sample',
#        'Found in Sample: [S325] F22: 131C, Sample',
#        'Found in Sample: [S326] F22: 132N, Sample',
#        'Found in Sample: [S327] F22: 132C, Sample',
#        'Found in Sample: [S328] F22: 133N, Sample',
#        'Found in Sample: [S329] F22: 133C, Sample',
#        'Found in Sample: [S330] F22: 134N, Sample',
#        'Found in Sample: [S331] F22: 134C, Sample',
#        'Found in Sample: [S332] F22: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "098": "yqaE",
    "174": "mhpRp2",
    '176': 'ygiW_1',
    '178': 'ygiW_2',
    '180': 'sohA',
    '182': 'kbpp4',
    '186': 'elaB',
    '188': 'rcsBp2',
    '190': 'flda',
    '192': 'galEp1',
    '194': 'ompRp3',
    '196': 'tisB',
    '233': 'gyrA',
    '829': 'acrZ',
    '837': 'Control',
    '839': 'Control2'
}

gc_dict = {
    'S': 'stationary',
}

file = "../../../data/mass-spec/20241216/HJ_20241216_OTE_AurTS25_setR.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'stationary'), ('839', 'stationary')]
# sample  Sum PEP Score  # Peptides Gene Symbol   condition      acrZ      elaB  \
# 0               0.911           1        norW  stationary  1.316680  0.681443
# 1               0.920           1        trpR  stationary  1.267810  0.959285
# 2               0.924           1        surA  stationary  1.037301  0.896630
# 4               0.933           1        dsbD  stationary  0.752047  1.503037
# 5               0.952           1        yhaL  stationary  0.454218  0.578086
#
# sample      flda    galEp1      gyrA     kbpp4    mhpRp2    ompRp3    rcsBp2  \
# 0       1.272515  1.647433  0.747726  2.237095  1.928450  1.087173  1.180665
# 1       1.010297  0.830112  1.026007  0.925707  0.800740  0.879506  0.820275
# 2       1.025973  0.677026  0.900269  0.884085  0.733003  0.670829  0.678053
# 4       0.770077  1.854238  1.384005  0.936631  1.186415  1.367952  1.232351
# 5       0.403710  0.300847  0.616674  0.360849  0.423177  0.347223  0.288028
#
# sample      sohA      tisB    ygiW_1    ygiW_2      yqaE Control      date
# 0       2.238188  0.549148  1.006547  1.062889  1.555550     837  20241216
# 1       0.844536  0.721608  0.916456  0.988593  0.811316     837  20241216
# 2       0.832895  0.749327  0.768103  0.770285  0.720641     837  20241216
# 4       1.391548  1.667145  0.663111  0.643454  1.396339     837  20241216
# 5       0.350875  0.562299  0.290801  0.288333  0.443426     837  20241216

# %%
df = pd.read_excel("../../../data/mass-spec/20241216/HJ_20241216_OTE_AurTS25_setB.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '975P',
#        '977P', '979P', '981P', '983P', '985P', '837P', '192D', '829D', '831D',
#        '833D', '837D', '839D', '841D', '843D', '851D',
#        'Found in Sample: [S297] F21: 126, Sample',
#        'Found in Sample: [S299] F21: 127N, Sample',
#        'Found in Sample: [S300] F21: 127C, Sample',
#        'Found in Sample: [S301] F21: 128N, Sample',
#        'Found in Sample: [S302] F21: 128C, Sample',
#        'Found in Sample: [S303] F21: 129N, Sample',
#        'Found in Sample: [S304] F21: 129C, Sample',
#        'Found in Sample: [S305] F21: 130N, Sample',
#        'Found in Sample: [S306] F21: 130C, Sample',
#        'Found in Sample: [S307] F21: 131N, Sample',
#        'Found in Sample: [S308] F21: 131C, Sample',
#        'Found in Sample: [S309] F21: 132N, Sample',
#        'Found in Sample: [S310] F21: 132C, Sample',
#        'Found in Sample: [S311] F21: 133N, Sample',
#        'Found in Sample: [S312] F21: 133C, Sample',
#        'Found in Sample: [S313] F21: 134N, Sample',
#        'Found in Sample: [S314] F21: 134C, Sample',
#        'Found in Sample: [S315] F21: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "975": "yqaE",
    "977": "furpb",
    '979': 'flda',
    '981': 'ihfAp',
    '983': 'ompRp3',
    '985': 'ecnb',
    '829': 'acrZ',
    '831': 'acrZ_2',
    '833': 'marRp',
    '841': 'dicCp',
    '843': 'yqjE_2',
    '851': 'galEp1',
    '192': 'gyrA',
    '829': 'acrZ',
    '837': 'Control_medium',
    '839': 'Control_short'
}


gc_dict = {
    'P': 'phenazine',
    'D': 'dipyridyl',
}

file = "../../../data/mass-spec/20241216/HJ_20241216_OTE_AurTS25_setB.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'dipyridyl'), ('839', 'dipyridyl'), ('837', 'phenazine')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition      acrZ    acrZ_2  \
# 0               0.786           1        yciX  dipyridyl  1.512084  1.264988
# 2               0.788           1        wzzB  dipyridyl  1.615129  1.587534
# 3               0.820           1        dgcP  dipyridyl  0.628996  1.577660
# 4               0.825           1        sufD  dipyridyl  0.649976  1.143590
# 5               0.832           1        proB  dipyridyl  1.246799  1.239976
#
# sample     dicCp    galEp1      gyrA     marRp    yqjE_2 Control      date
# 0       0.932717  1.841354  5.193230  0.906386  1.212574     837  20241216
# 2       1.126434  1.563038  1.123154  1.439338  1.675628     837  20241216
# 3       0.450040  0.507812  0.376841  0.706812  0.979685     837  20241216
# 4       0.996412  0.905617  0.850558  0.872840  1.489553     837  20241216
# 5       1.121574  1.309054  0.939731  1.382404  1.127836     837  20241216

# %%
df = pd.read_excel("../../../data/mass-spec/20241221/HJ_20241221_OTE_AurTS25_setR.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '231A',
#        '233A', '481A', '839A', '192D', '829D', '831D', '833D', '839D', '841D',
#        '843D', '851D', '182X', '839X', '849X', '853X',
#        'Found in Sample: [S370] F26: 126, Sample',
#        'Found in Sample: [S388] F26: 127N, Sample',
#        'Found in Sample: [S389] F26: 127C, Sample',
#        'Found in Sample: [S390] F26: 128N, Sample',
#        'Found in Sample: [S391] F26: 128C, Sample',
#        'Found in Sample: [S392] F26: 129N, Sample',
#        'Found in Sample: [S393] F26: 129C, Sample',
#        'Found in Sample: [S394] F26: 130N, Sample',
#        'Found in Sample: [S395] F26: 130C, Sample',
#        'Found in Sample: [S396] F26: 131N, Sample',
#        'Found in Sample: [S397] F26: 131C, Sample',
#        'Found in Sample: [S398] F26: 132N, Sample',
#        'Found in Sample: [S399] F26: 132C, Sample',
#        'Found in Sample: [S400] F26: 133N, Sample',
#        'Found in Sample: [S401] F26: 133C, Sample',
#        'Found in Sample: [S402] F26: 134N, Sample',
#        'Found in Sample: [S403] F26: 134C, Sample',
#        'Found in Sample: [S404] F26: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "231": "yahC",
    "233": "gyrA",
    '839': 'Control',
    '192': 'galEp1',
    '481': 'rcsBp2',
    '829': 'acrZ',
    '831': 'acrZ_2',
    '833': 'marRp',
    '841': 'dicCp',
    '843': 'aceBp',
    '851': 'yqjE_2',
    '182': 'kbpp4',
    '849': 'rcsDp',
    '853': 'araCp'
}


gc_dict = {
    'A': 'arabinose',
    'D': 'dipyridyl',
    'X': 'xylose',
    
}

file = "../../../data/mass-spec/20241221/HJ_20241221_OTE_AurTS25_setR.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('839', 'arabinose'), ('839', 'dipyridyl'), ('839', 'xylose')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition      gyrA    rcsBp2  \
# 0               0.889           1        thrB  arabinose  1.631692  0.741472
# 1               0.895           1        infC  arabinose  0.533457  0.726065
# 2               0.955           1        purF  arabinose  0.996238  0.418939
# 3               0.956           1        cusS  arabinose  1.493464  0.752647
# 4               0.959           1        glgS  arabinose  0.629279  0.601210
#
# sample      yahC Control      date
# 0       0.354672     839  20241221
# 1       1.221724     839  20241221
# 2       0.307304     839  20241221
# 3       0.748111     839  20241221
# 4       0.187021     839  20241221

# %%
df = pd.read_excel("../../../data/mass-spec/20241221/HJ_20241221_OTE_AurTS25_setB.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '235A',
#        '237A', '239A', '241A', '484A', '489A', '492A', '496A', '498A', '500A',
#        '839A', '186G', '214G', '837G', '855G', '981G',
#        'Found in Sample: [S369] F25: 126, Sample',
#        'Found in Sample: [S371] F25: 127N, Sample',
#        'Found in Sample: [S372] F25: 127C, Sample',
#        'Found in Sample: [S373] F25: 128N, Sample',
#        'Found in Sample: [S374] F25: 128C, Sample',
#        'Found in Sample: [S375] F25: 129N, Sample',
#        'Found in Sample: [S376] F25: 129C, Sample',
#        'Found in Sample: [S377] F25: 130N, Sample',
#        'Found in Sample: [S378] F25: 130C, Sample',
#        'Found in Sample: [S379] F25: 131N, Sample',
#        'Found in Sample: [S380] F25: 131C, Sample',
#        'Found in Sample: [S381] F25: 132N, Sample',
#        'Found in Sample: [S382] F25: 132C, Sample',
#        'Found in Sample: [S383] F25: 133N, Sample',
#        'Found in Sample: [S384] F25: 133C, Sample',
#        'Found in Sample: [S385] F25: 134N, Sample',
#        'Found in Sample: [S386] F25: 134C, Sample',
#        'Found in Sample: [S387] F25: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    "235": "TSS_1414_1",
    "237": "TSS_1414_2",
    '239': 'araB_1',
    '241': 'araB_2',
    '484': 'tmaR_1',
    '489': 'tmaR_2',
    '496': 'mglB_1',
    '492': 'tmaR_3',
    '498': 'rspA_1',
    '500': 'rspA_2',
    '186': 'elaB',
    '214': 'ybaY',
    '855': 'mglB_2',
    '837': 'Control_medium',
    '839': 'Control_long',
    '981': 'ihfAp'
}


gc_dict = {
    'A': 'arabinose',
    'G': 'glucose',
    'D': 'dipyridyl',
    'X': 'Xylose'
}

file = "../../../data/mass-spec/20241221/HJ_20241221_OTE_AurTS25_setB.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('839', 'arabinose'), ('837', 'glucose')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition  TSS_1414_1  \
# 0               0.893           1        fliJ  arabinose    0.788823
# 1               0.897           1        rsmB  arabinose    0.801821
# 2               0.910           1        coaA  arabinose    1.098031
# 3               0.915           1        leuA  arabinose    0.996133
# 5               0.973           1        atpE  arabinose    1.097126
#
# sample  TSS_1414_2    araB_1    araB_2    mglB_1    rspA_1    rspA_2  \
# 0         0.580309  0.397554  1.290206  0.504285  0.477320  1.493587
# 1         0.546104  0.614557  0.741948  0.743646  0.692434  0.611287
# 2         0.837686  0.764267  0.967240  0.920609  0.935451  0.901920
# 3         0.612568  0.633428  0.864578  0.756081  0.810606  0.803751
# 5         1.057475  0.411151  0.748893  0.980539  0.719754  0.820525
#
# sample    tmaR_1    tmaR_2    tmaR_3 Control      date
# 0       0.750334  0.250900  0.619301     839  20241221
# 1       0.763965  0.529733  0.720850     839  20241221
# 2       0.954956  0.542322  0.983650     839  20241221
# 3       0.846547  0.268689  0.686371     839  20241221
# 5       0.859389  0.206021  0.539652     839  20241221

# %%
df = pd.read_excel("../../../data/mass-spec/20250113_analysis/HJ_20250112_OTE_AurTS25_setR.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '738J',
#        '740J', '742J', '744J', '746J', '748J', '839J', '186G', '214G', '837G',
#        '855G', '981G', '182X', '839X', '849X', '853X',
#        'Found in Sample: [S406] F28: 126, Sample',
#        'Found in Sample: [S424] F28: 127N, Sample',
#        'Found in Sample: [S425] F28: 127C, Sample',
#        'Found in Sample: [S426] F28: 128N, Sample',
#        'Found in Sample: [S427] F28: 128C, Sample',
#        'Found in Sample: [S428] F28: 129N, Sample',
#        'Found in Sample: [S429] F28: 129C, Sample',
#        'Found in Sample: [S430] F28: 130N, Sample',
#        'Found in Sample: [S431] F28: 130C, Sample',
#        'Found in Sample: [S432] F28: 131N, Sample',
#        'Found in Sample: [S433] F28: 131C, Sample',
#        'Found in Sample: [S434] F28: 132N, Sample',
#        'Found in Sample: [S435] F28: 132C, Sample',
#        'Found in Sample: [S436] F28: 133N, Sample',
#        'Found in Sample: [S437] F28: 133C, Sample',
#        'Found in Sample: [S438] F28: 134N, Sample',
#        'Found in Sample: [S439] F28: 134C, Sample',
#        'Found in Sample: [S440] F28: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '738': 'cpxR',
    "740": "intE",
    "742": "yadE2",
    '744': 'ybeDp',
    '746': 'ompRp2',
    '748': 'acrA',
    '839': 'Control_long',
    '186': 'elaB',
    '214': 'ybaY',
    '837': 'Control_medium',
    '855': 'mglB_2',
    '981': 'ihfAp',
    '182': 'kbpp4',
    '839': 'Control_long',
    '849': 'rcsDp',
    '853': 'araCp',
}


gc_dict = {
    'J': 'gentamicin',
    'G': 'glucose',
    'X': 'Xylose'
}

file = "../../../data/mass-spec/20250113_analysis/HJ_20250112_OTE_AurTS25_setR.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('839', 'Xylose'), ('839', 'gentamicin'), ('837', 'glucose')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition     araCp     kbpp4  \
# 0               0.824           1        msbA    Xylose  0.879822  0.917583
# 1               0.843           1         bcp    Xylose  0.664953  0.832080
# 2               0.845           1        rsgA    Xylose  3.243423  0.549858
# 3               0.849           1        yhcN    Xylose  0.938077  0.693058
# 5               0.854           1        mukF    Xylose  0.522247  0.866596
#
# sample     rcsDp Control      date
# 0       0.962136     839  20250113
# 1       1.159247     839  20250113
# 2       0.603054     839  20250113
# 3       0.895952     839  20250113
# 5       1.057436     839  20250113

# %%
df = pd.read_excel("../../../data/mass-spec/20250113_analysis/HJ_20250112_OTE_AurTS25_setB.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '231A',
#        '233A', '235A', '237A', '239A', '241A', '481A', '484A', '489A', '492A',
#        '496A', '498A', '500A', '839A', '208S', '837S',
#        'Found in Sample: [S405] F27: 126, Sample',
#        'Found in Sample: [S407] F27: 127N, Sample',
#        'Found in Sample: [S408] F27: 127C, Sample',
#        'Found in Sample: [S409] F27: 128N, Sample',
#        'Found in Sample: [S410] F27: 128C, Sample',
#        'Found in Sample: [S411] F27: 129N, Sample',
#        'Found in Sample: [S412] F27: 129C, Sample',
#        'Found in Sample: [S413] F27: 130N, Sample',
#        'Found in Sample: [S414] F27: 130C, Sample',
#        'Found in Sample: [S415] F27: 131N, Sample',
#        'Found in Sample: [S416] F27: 131C, Sample',
#        'Found in Sample: [S417] F27: 132N, Sample',
#        'Found in Sample: [S418] F27: 132C, Sample',
#        'Found in Sample: [S419] F27: 133N, Sample',
#        'Found in Sample: [S420] F27: 133C, Sample',
#        'Found in Sample: [S421] F27: 134N, Sample',
#        'Found in Sample: [S422] F27: 134C, Sample',
#        'Found in Sample: [S423] F27: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '231': 'yahC',
    "233": "gyrA",
    "235": "TSS_1414_1",
    '237': 'TSS_1414_2',
    '239': 'araB_1',
    '241': 'araB_2',
    '481': 'rcsBp2',
    '484': 'tmaR_1',
    '489': 'tmaR_2',
    '492': 'tmaR_3',
    '496': 'mglB_1',
    '498': 'rspA_1',
    '500': 'rspA_2',
    '839': 'Control_long',
    '837': 'Control_medium',
    '208': 'yjbJ'
}


gc_dict = {
    'S': 'stationary',
    'A': 'arabinose',
}

file = "../../../data/mass-spec/20250113_analysis/HJ_20250112_OTE_AurTS25_setB.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('839', 'arabinose'), ('837', 'stationary')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition  TSS_1414_1  \
# 0               0.768           1        hofO  arabinose    1.308145
# 2               0.790           1        yafC  arabinose    0.982845
# 3               0.798           1        frmB  arabinose    1.421125
# 4               0.799           1        norV  arabinose    2.290059
# 6               0.816           1        ychA  arabinose    1.554991
#
# sample  TSS_1414_2    araB_1    araB_2      gyrA    mglB_1    rcsBp2  \
# 0         1.526434  1.000012  2.336084  0.465551  6.369113  2.105414
# 2         0.681712  0.619041  0.665986  0.221118  0.792834  0.790149
# 3         0.774491  0.754823  1.101900  0.233028  1.202157  0.950326
# 4         2.843075  1.773900  0.863506  4.902626  2.504637  1.184075
# 6         1.015837  0.991658  0.847218  0.216243  1.105474  0.960795
#
# sample    rspA_1    rspA_2    tmaR_1    tmaR_2    tmaR_3      yahC Control  \
# 0       1.163811  1.641571  1.649926  1.597178  1.756839  0.488055     839
# 2       0.985623  1.050881  0.631255  0.521170  0.870506  0.369484     839
# 3       0.768570  1.129668  0.805793  0.645407  1.054173  0.431177     839
# 4       1.154494  1.077868  0.792076  1.473089  1.734641  1.149344     839
# 6       0.961867  1.310198  0.773011  0.737198  1.073679  0.498006     839
#
# sample      date
# 0       20250113
# 2       20250113
# 3       20250113
# 4       20250113
# 6       20250113

# %%
df = pd.read_excel("../../../data/mass-spec/20250124_analysis/HJ_20250122_OTE_AurTS25_setB.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '738J',
#        '740J', '742J', '744J', '746J', '748J', '839J', '975P', '977P', '979P',
#        '981P', '983P', '985P', '839P', '212S', '839S',
#        'Found in Sample: [S441] F29: 126, Sample',
#        'Found in Sample: [S443] F29: 127N, Sample',
#        'Found in Sample: [S444] F29: 127C, Sample',
#        'Found in Sample: [S445] F29: 128N, Sample',
#        'Found in Sample: [S446] F29: 128C, Sample',
#        'Found in Sample: [S447] F29: 129N, Sample',
#        'Found in Sample: [S448] F29: 129C, Sample',
#        'Found in Sample: [S449] F29: 130N, Sample',
#        'Found in Sample: [S450] F29: 130C, Sample',
#        'Found in Sample: [S451] F29: 131N, Sample',
#        'Found in Sample: [S452] F29: 131C, Sample',
#        'Found in Sample: [S453] F29: 132N, Sample',
#        'Found in Sample: [S454] F29: 132C, Sample',
#        'Found in Sample: [S455] F29: 133N, Sample',
#        'Found in Sample: [S456] F29: 133C, Sample',
#        'Found in Sample: [S457] F29: 134N, Sample',
#        'Found in Sample: [S458] F29: 134C, Sample',
#        'Found in Sample: [S459] F29: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '738': 'cpxR',
    "740": "intE",
    "742": "yadE2",
    '744': 'ybeDp',
    '746': 'ompRp2',
    '748': 'acrA',
    '839': 'Control_long',
    '975': 'elaB',
    '977': 'furpb',
    '979': 'flda',
    '981': 'ihfAp',
    '983': 'ompRp3',
    '985': 'ecnb',
    '839': 'Control_long',
    '212': 'yadI',
}


gc_dict = {
    'S': 'stationary',
    'J': 'gentamicin',
    'P': 'phenazine'
}

file = "../../../data/mass-spec/20250124_analysis/HJ_20250122_OTE_AurTS25_setB.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('839', 'gentamicin'), ('839', 'phenazine'), ('839', 'stationary')]
# sample  Sum PEP Score  # Peptides Gene Symbol   condition      acrA      cpxR  \
# 4               0.788           1        tktA  gentamicin  0.409415  1.454584
# 8               0.809           1         gmk  gentamicin  0.825368  1.546160
# 9               0.811           1        efeO  gentamicin  0.941927  1.296091
# 10              0.812           1        sodA  gentamicin  0.280900  1.480930
# 11              0.814           1        frmB  gentamicin  0.511624  2.821971
#
# sample      intE    ompRp2     yadE2     ybeDp Control      date
# 4       0.774908  0.563699  0.901669  0.509385     839  20250124
# 8       1.224927  0.772202  1.152430  0.866254     839  20250124
# 9       1.328142  1.149461  1.435018  0.847154     839  20250124
# 10      0.407378  0.829881  0.467087  0.320772     839  20250124
# 11      1.239974  0.685529  1.141037  0.445629     839  20250124

# %%
df = pd.read_excel("../../../data/mass-spec/20250124_analysis/HJ_20250122_OTE_AurTS25_setR.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '875G',
#        '878G', '882G', '885G', '889G', '892G', '895G', '898G', '905G', '083G',
#        '085G', '837G', '893G', '087S', '089S', '837S',
#        'Found in Sample: [S442] F30: 126, Sample',
#        'Found in Sample: [S460] F30: 127N, Sample',
#        'Found in Sample: [S461] F30: 127C, Sample',
#        'Found in Sample: [S462] F30: 128N, Sample',
#        'Found in Sample: [S463] F30: 128C, Sample',
#        'Found in Sample: [S464] F30: 129N, Sample',
#        'Found in Sample: [S465] F30: 129C, Sample',
#        'Found in Sample: [S466] F30: 130N, Sample',
#        'Found in Sample: [S467] F30: 130C, Sample',
#        'Found in Sample: [S468] F30: 131N, Sample',
#        'Found in Sample: [S469] F30: 131C, Sample',
#        'Found in Sample: [S470] F30: 132N, Sample',
#        'Found in Sample: [S471] F30: 132C, Sample',
#        'Found in Sample: [S472] F30: 133N, Sample',
#        'Found in Sample: [S473] F30: 133C, Sample',
#        'Found in Sample: [S474] F30: 134N, Sample',
#        'Found in Sample: [S475] F30: 134C, Sample',
#        'Found in Sample: [S476] F30: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '875': 'uofp',
    "878": "lpp1",
    "882": "lpp2",
    '885': 'blr',
    '889': 'ybiY1',
    '892': 'ybiY2',
    '895': 'ybiY3',
    '898': 'araCp_2',
    '905': 'zapB1',
    '083': 'zapB2',
    '085': 'zapB3',
    '837': 'Control_medium',
    '839': 'Control_long',
    '087': 'ompRp2',
    '089': 'acrA',
}


gc_dict = {
    'G': 'glucose',
    'S': 'stationary',
}

file = "../../../data/mass-spec/20250124_analysis/HJ_20250122_OTE_AurTS25_setR.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'glucose'), ('837', 'stationary')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition   araCp_2       blr  \
# 0               0.723           1        yciH   glucose  1.087945  1.132266
# 1               0.729           1        rpsR   glucose  0.735674  0.979305
# 2               0.736           1        glgC   glucose  1.178218  1.041815
# 5               0.757           1        waaY   glucose  0.683231  0.760432
# 7               0.806           1        yhiL   glucose  1.126763  1.137958
#
# sample      lpp1      lpp2      uofp     ybiY1     ybiY2     ybiY3     zapB1  \
# 0       0.777860  1.688388  0.952203  0.847351  0.958291  0.957114  0.994442
# 1       1.319458  0.658870  1.010451  0.561976  0.890785  0.858243  0.898801
# 2       0.800652  1.153409  0.897874  1.602547  0.878652  0.975126  0.969341
# 5       0.516711  0.979852  0.628727  0.642156  0.699372  0.798471  0.828153
# 7       1.254438  1.357985  1.222563  0.965354  1.141499  1.193773  1.778366
#
# sample     zapB2     zapB3 Control      date
# 0       0.883050  1.356597     837  20250124
# 1       1.246372  0.728843     837  20250124
# 2       1.168908  0.984162     837  20250124
# 5       0.636076  0.861841     837  20250124
# 7       1.021924  0.914313     837  20250124

# %%
df = pd.read_excel("../../../data/mass-spec/20250213_analysis/HJ_20250210_OTE_AurTS25_setB.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '853X',
#        '849X', '839X', '182X', '837S', '218S', '214S', '212S', '210S', '208S',
#        '837N', '210N', '214N', '212N', '208N', '098N',
#        'Found in Sample: [S477] F31: 126, Sample',
#        'Found in Sample: [S479] F31: 127N, Sample',
#        'Found in Sample: [S480] F31: 127C, Sample',
#        'Found in Sample: [S481] F31: 128N, Sample',
#        'Found in Sample: [S482] F31: 128C, Sample',
#        'Found in Sample: [S483] F31: 129N, Sample',
#        'Found in Sample: [S484] F31: 129C, Sample',
#        'Found in Sample: [S485] F31: 130N, Sample',
#        'Found in Sample: [S486] F31: 130C, Sample',
#        'Found in Sample: [S487] F31: 131N, Sample',
#        'Found in Sample: [S488] F31: 131C, Sample',
#        'Found in Sample: [S489] F31: 132N, Sample',
#        'Found in Sample: [S490] F31: 132C, Sample',
#        'Found in Sample: [S491] F31: 133N, Sample',
#        'Found in Sample: [S492] F31: 133C, Sample',
#        'Found in Sample: [S493] F31: 134N, Sample',
#        'Found in Sample: [S494] F31: 134C, Sample',
#        'Found in Sample: [S495] F31: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '853': 'araCp',
    "849": "rcsDp",
    "839": "Control_long",
    '182': 'kbpp4',
    '837': 'Control_medium',
    '218': 'yqjE',
    '214': 'ybaY',
    '212': 'yadI',
    '210': 'yadE',
    '208': 'yjbJ',
    '098': 'yqaE',
}


gc_dict = {
    'X': 'xylose',
    'S': 'stationary',
    'N': 'salt'
}

file = "../../../data/mass-spec/20250213_analysis/HJ_20250210_OTE_AurTS25_setB.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'salt'), ('837', 'stationary'), ('839', 'xylose')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition      yadE      yadI  \
# 0               0.739           1        rhsD      salt  0.252366  0.883132
# 1               0.744           1        mutL      salt  0.521331  0.757295
# 2               0.760           1        ycgM      salt  0.388302  0.723857
# 3               0.762           1        proS      salt  1.045921  0.936234
# 4               0.774           1        rpsG      salt  1.779912  1.093493
#
# sample      ybaY      yjbJ      yqaE Control      date
# 0       1.623022  0.839576  0.834788     837  20250213
# 1       0.651412  0.700765  1.109054     837  20250213
# 2       0.814457  0.762704  0.845154     837  20250213
# 3       0.906010  0.946648  1.039943     837  20250213
# 4       1.249677  1.165773  1.389783     837  20250213

# %%
df = pd.read_excel("../../../data/mass-spec/20250213_analysis/HJ_20250210_OTE_AurTS25_setR.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '839G',
#        '981G', '905G', '898G', '895G', '892G', '889G', '885G', '888G', '878G',
#        '875G', '855G', '214G', '186G', '085G', '083G',
#        'Found in Sample: [S478] F32: 126, Sample',
#        'Found in Sample: [S496] F32: 127N, Sample',
#        'Found in Sample: [S497] F32: 127C, Sample',
#        'Found in Sample: [S498] F32: 128N, Sample',
#        'Found in Sample: [S499] F32: 128C, Sample',
#        'Found in Sample: [S500] F32: 129N, Sample',
#        'Found in Sample: [S501] F32: 129C, Sample',
#        'Found in Sample: [S502] F32: 130N, Sample',
#        'Found in Sample: [S503] F32: 130C, Sample',
#        'Found in Sample: [S504] F32: 131N, Sample',
#        'Found in Sample: [S505] F32: 131C, Sample',
#        'Found in Sample: [S506] F32: 132N, Sample',
#        'Found in Sample: [S507] F32: 132C, Sample',
#        'Found in Sample: [S508] F32: 133N, Sample',
#        'Found in Sample: [S509] F32: 133C, Sample',
#        'Found in Sample: [S510] F32: 134N, Sample',
#        'Found in Sample: [S511] F32: 134C, Sample',
#        'Found in Sample: [S512] F32: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '905': 'zapB1',
    "981": "ihfAp",
    "839": "Control_long",
    '898': 'araCp_2',
    '895': 'ybiY3',
    '892': 'ybiY2',
    '889': 'ybiY1',
    '885': 'blr',
    '882': 'lpp2',
    '878': 'lpp1',
    '875': 'uofp',
    '855': 'mglB_2',
    '214': 'ybaY',
    '186': 'elaB',
    '085': 'zapB3',
    '083': 'zapB2'
}


gc_dict = {
    'G': 'glucose',
    'X': 'xylose'
}

file = "../../../data/mass-spec/20250213_analysis/HJ_20250210_OTE_AurTS25_setR.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('839', 'glucose')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition   araCp_2       blr  \
# 2               0.820           1        ftsK   glucose  3.420193  2.804644
# 4               0.854           1        qmcA   glucose  0.437880  0.353878
# 5               0.859           1        acrA   glucose  0.248349  0.414543
# 6               0.861           1        yjiA   glucose  1.633433  1.701150
# 7               0.863           1        yheO   glucose  1.066978  0.829802
#
# sample      elaB     ihfAp      lpp1    mglB_2      uofp      ybaY     ybiY1  \
# 2       2.474087  2.600134  2.944851  1.948633  3.255254  3.147926  2.312953
# 4       0.480114  0.489737  0.526355  0.595054  0.463094  0.359443  0.459994
# 5       0.511582  0.291596  0.369241  0.554222  0.326727  0.402525  0.384973
# 6       1.546565  1.468768  1.583969  1.481891  1.579455  1.588070  1.424537
# 7       1.168245  1.043297  0.991722  2.620541  1.057348  0.851984  0.949197
#
# sample     ybiY2     ybiY3     zapB1     zapB2     zapB3 Control      date
# 2       3.280453  2.807136  3.127582  2.541482  2.583236     839  20250213
# 4       0.431738  0.618316  0.579967  0.480053  0.467464     839  20250213
# 5       0.288640  0.313225  0.210324  0.406350  0.437225     839  20250213
# 6       1.610801  1.631642  1.472283  1.762430  1.858685     839  20250213
# 7       0.728524  1.074952  1.086273  1.138556  1.075927     839  20250213

# %%
df = pd.read_excel("../../../data/mass-spec/20250303_analysis/HJ_20250303_OTE_AurTS25_set1.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '851D',
#        '843D', '841D', '839D', '833D', '831D', '829D', '192D', '985P', '983P',
#        '981P', '979P', '977P', '975P', '839P', '837P',
#        'Found in Sample: [S549] F35: 126, Sample',
#        'Found in Sample: [S551] F35: 127N, Sample',
#        'Found in Sample: [S552] F35: 127C, Sample',
#        'Found in Sample: [S553] F35: 128N, Sample',
#        'Found in Sample: [S554] F35: 128C, Sample',
#        'Found in Sample: [S555] F35: 129N, Sample',
#        'Found in Sample: [S556] F35: 129C, Sample',
#        'Found in Sample: [S557] F35: 130N, Sample',
#        'Found in Sample: [S558] F35: 130C, Sample',
#        'Found in Sample: [S559] F35: 131N, Sample',
#        'Found in Sample: [S560] F35: 131C, Sample',
#        'Found in Sample: [S561] F35: 132N, Sample',
#        'Found in Sample: [S562] F35: 132C, Sample',
#        'Found in Sample: [S563] F35: 133N, Sample',
#        'Found in Sample: [S564] F35: 133C, Sample',
#        'Found in Sample: [S565] F35: 134N, Sample',
#        'Found in Sample: [S566] F35: 134C, Sample',
#        'Found in Sample: [S567] F35: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '851': 'yqjE_2',
    "843": "aceBp",
    "841": "dicCp",
    '839': 'Control_long',
    '833': 'marRp',
    '831': 'acrZ_2',
    '829': 'acrZ',
    '192': 'galEp1',
    '985': 'ecnb',
    '983': 'ompRp3',
    '981': 'ihfAp',
    '979': 'flda',
    '977': 'furpb',
    '975': 'pheMp',
    '837': 'Control_medium',
}


gc_dict = {
    'D': 'dipyridyl',
    'P': 'phenazine'
}

file = "../../../data/mass-spec/20250303_analysis/HJ_20250303_OTE_AurTS25_set1.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('839', 'dipyridyl'), ('839', 'phenazine'), ('837', 'phenazine')]
# sample  Sum PEP Score  # Peptides Gene Symbol  condition     aceBp      acrZ  \
# 0               0.816           1        aroA  dipyridyl  0.772941  0.749851
# 1               0.832           1         usg  dipyridyl  1.079742  1.374930
# 2               0.833           1         ivy  dipyridyl  0.643856  0.650565
# 3               0.838           1        cyoB  dipyridyl  1.033824  0.938649
# 4               0.847           1        dtpA  dipyridyl  0.938031  1.243811
#
# sample    acrZ_2     dicCp    galEp1     marRp    yqjE_2 Control      date
# 0       0.533904  0.833400  0.686652  0.543288  0.700047     839  20250303
# 1       1.710269  1.031153  0.800553  1.050089  0.965473     839  20250303
# 2       0.525113  0.720149  0.612787  0.512858  0.822969     839  20250303
# 3       0.893645  0.986591  0.648758  0.807220  0.872551     839  20250303
# 4       1.040141  1.572856  0.588818  1.699929  0.811226     839  20250303

# %%
df = pd.read_excel("../../../data/mass-spec/20250303_analysis/HJ_20250303_OTE_AurTS25_set2.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '188$',
#        '186$', '182$', '176$', '174$', '098$', '089$', '087$', '837N', '218N',
#        '214N', '210N', '837$', '839$', '194$', '190$',
#        'Found in Sample: [S550] F36: 126, Sample',
#        'Found in Sample: [S568] F36: 127N, Sample',
#        'Found in Sample: [S569] F36: 127C, Sample',
#        'Found in Sample: [S570] F36: 128N, Sample',
#        'Found in Sample: [S571] F36: 128C, Sample',
#        'Found in Sample: [S572] F36: 129N, Sample',
#        'Found in Sample: [S573] F36: 129C, Sample',
#        'Found in Sample: [S574] F36: 130N, Sample',
#        'Found in Sample: [S575] F36: 130C, Sample',
#        'Found in Sample: [S576] F36: 131N, Sample',
#        'Found in Sample: [S577] F36: 131C, Sample',
#        'Found in Sample: [S578] F36: 132N, Sample',
#        'Found in Sample: [S579] F36: 132C, Sample',
#        'Found in Sample: [S580] F36: 133N, Sample',
#        'Found in Sample: [S581] F36: 133C, Sample',
#        'Found in Sample: [S582] F36: 134N, Sample',
#        'Found in Sample: [S583] F36: 134C, Sample',
#        'Found in Sample: [S584] F36: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '188': 'rcsBp2',
    "186": "elaB",
    "176": "ygiW_1",
    '174': 'mhpRp2',
    '098': 'yqaE',
    '089': 'acrA',
    '087': 'ompRp2',
    '837': 'Control_medium',
    '218': 'yqjE',
    '214': 'ybaY',
    '210': 'yadE',
    '839': 'Control_long',
    '194': 'ompRp3',
    '190': 'fldA',
}


gc_dict = {
    '$': 'stationary, high vol',
    'N': 'salt'
}

file = "../../../data/mass-spec/20250303_analysis/HJ_20250303_OTE_AurTS25_set2.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'salt'), ('839', 'stationary, high vol'), ('837', 'stationary, high vol')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition      yadE      ybaY  \
# 0               0.819           1        trpA      salt  0.756288  1.249102
# 2               0.831           1        yibL      salt  1.608012  2.197494
# 3               0.836           1        aroL      salt  0.343629  0.323368
# 4               0.844           1        trxC      salt  1.299431  1.269853
# 5               0.849           1        lpoA      salt  0.569038  0.807930
#
# sample      yqjE Control      date
# 0       0.704072     837  20250303
# 2       1.098042     837  20250303
# 3       0.591148     837  20250303
# 4       0.505469     837  20250303
# 5       0.707716     837  20250303

# %%
df = pd.read_excel("../../../data/mass-spec/20250307/HJ_20250325_OTE_AurTS25_0307.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '839C2',
#        '738C2', '655C2', '653C2', '839C1', '738C1', '655C1', '653C1', '837P',
#        '196P', '186P', '985L', '837L', '839H', '651H', '216H',
#        'Found in Sample: [S586] F38: 126, Sample',
#        'Found in Sample: [S604] F38: 127N, Sample',
#        'Found in Sample: [S605] F38: 127C, Sample',
#        'Found in Sample: [S606] F38: 128N, Sample',
#        'Found in Sample: [S607] F38: 128C, Sample',
#        'Found in Sample: [S608] F38: 129N, Sample',
#        'Found in Sample: [S609] F38: 129C, Sample',
#        'Found in Sample: [S610] F38: 130N, Sample',
#        'Found in Sample: [S611] F38: 130C, Sample',
#        'Found in Sample: [S612] F38: 131N, Sample',
#        'Found in Sample: [S613] F38: 131C, Sample',
#        'Found in Sample: [S614] F38: 132N, Sample',
#        'Found in Sample: [S615] F38: 132C, Sample',
#        'Found in Sample: [S616] F38: 133N, Sample',
#        'Found in Sample: [S617] F38: 133C, Sample',
#        'Found in Sample: [S618] F38: 134N, Sample',
#        'Found in Sample: [S619] F38: 134C, Sample',
#        'Found in Sample: [S620] F38: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '839': 'Control_long',
    "738": "cpxR",
    "655": "cusC2",
    '653': 'cusC',
    '837': 'Control_medium',
    '196': 'tisB',
    '186': 'elaB',
    '985': 'ecnb',
    '651': 'yagB2',
    '216': 'yagB',
}


gc_dict = {
    'P': 'H2O2',
    'H': 'heatshock',
    'C1': 'copper1',
    'C2': 'copper2',
    'L': 'Leucine'
}

file = "../../../data/mass-spec/20250307/HJ_20250325_OTE_AurTS25_0307.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'H2O2'), ('837', 'Leucine'), ('839', 'copper1'), ('839', 'copper2'), ('839', 'heatshock')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition      elaB      tisB  \
# 0               0.859           1        glpQ      H2O2  0.723982  0.842354
# 1               0.861           1        ykgE      H2O2  1.099493  0.853349
# 3               0.873           1        yihF      H2O2  0.898234  0.858271
# 4               0.876           1        hemB      H2O2  0.785612  0.692563
# 6               0.886           1        ubiI      H2O2  0.970158  0.987582
#
# sample Control      date
# 0          837  20250307
# 1          837  20250307
# 3          837  20250307
# 4          837  20250307
# 6          837  20250307

# %%
df = pd.read_excel("../../../data/mass-spec/20250326/HJ_20250325_OTE_AurTS25_0313.xlsx")
df.columns
# Out:
# Index(['Checked', 'Protein FDR Confidence: Combined', 'Master', 'Accession',
#        'Description', 'Exp. q-value: Combined', 'Sum PEP Score',
#        'Coverage [%]', '# Peptides', '# PSMs', '# Unique Peptides', '# AAs',
#        'MW [kDa]', 'calc. pI', 'Score Sequest HT: Sequest HT',
#        '# Peptides (by Search Engine): Sequest HT', 'Biological Process',
#        'Cellular Component', 'Molecular Function', 'Pfam IDs',
#        'Entrez Gene ID', 'Ensembl Gene ID', 'Gene Symbol', 'Gene ID',
#        'WikiPathways', '# Protein Pathway Groups', '# Razor Peptides', '985Le',
#        '837Le', '837LB2', '657LB2', '212LB2', '837LB1', '657LB1', '212LB1',
#        '837P', '196P', '186P', '839H', '651H', '216H',
#        'Found in Sample: [S585] F37: 126, Sample',
#        'Found in Sample: [S587] F37: 127N, Sample',
#        'Found in Sample: [S588] F37: 127C, Sample',
#        'Found in Sample: [S589] F37: 128N, Sample',
#        'Found in Sample: [S590] F37: 128C, Sample',
#        'Found in Sample: [S591] F37: 129N, Sample',
#        'Found in Sample: [S592] F37: 129C, Sample',
#        'Found in Sample: [S593] F37: 130N, Sample',
#        'Found in Sample: [S594] F37: 130C, Sample',
#        'Found in Sample: [S595] F37: 131N, Sample',
#        'Found in Sample: [S596] F37: 131C, Sample',
#        'Found in Sample: [S597] F37: 132N, Sample',
#        'Found in Sample: [S598] F37: 132C, Sample',
#        'Found in Sample: [S599] F37: 133N, Sample',
#        'Found in Sample: [S600] F37: 133C, Sample',
#        'Found in Sample: [S601] F37: 134N, Sample',
#        'Found in Sample: [S602] F37: 134C, Sample',
#        'Found in Sample: [S603] F37: 135N, Sample', '# Protein Groups',
#        'Modifications'],
#       dtype='object')

# %%
sample_dict = {
    '839': 'Control_long',
    "738": "cpxR",
    "657": "icdC",
    '212': 'yadI',
    '837': 'Control_medium',
    '196': 'tisB',
    '186': 'elaB',
    '985': 'ecnb',
    '651': 'yagB2',
    '216': 'yagB',
}


gc_dict = {
    'P': 'H2O2',
    'H': 'heatshock',
    'LB1': 'LB1',
    'LB2': 'LB2',
    'Le': 'Leucine'
}

file = "../../../data/mass-spec/20250326/HJ_20250325_OTE_AurTS25_0313.xlsx"

out_df_list, control_list = parse_mass_spec(file, sample_dict, gc_dict)

print(control_list)
display(out_df_list[0].head(5))
df_list.extend(out_df_list)
# Out:
# [('837', 'H2O2'), ('837', 'LB1'), ('837', 'LB2'), ('837', 'Leucine'), ('839', 'heatshock')]
# sample  Sum PEP Score  # Peptides Gene Symbol condition      elaB      tisB  \
# 0               0.703           1        yedA      H2O2  0.893398  0.216459
# 2               0.715           1        clpA      H2O2  0.765301  1.118983
# 3               0.724           1        yeiQ      H2O2  0.308541  0.271059
# 4               0.728           1        gatY      H2O2  0.864040  0.626769
# 5               0.733           1        pfkB      H2O2  0.673172  0.811476
#
# sample Control      date
# 0          837  20250326
# 2          837  20250326
# 3          837  20250326
# 4          837  20250326
# 5          837  20250326

# %% [markdown]
# ## Combine all the data sets
#
# Now we can combine all datasets into a single dataframe.

# %%
df_combined = pd.concat([pd.melt(df, id_vars=['Sum PEP Score', '# Peptides', 'Gene Symbol', 'condition', 'Control', 'date'], value_name='enrichment') for df in df_list])

# %%
df_combined.reset_index(drop=True)
# Out:
#         Sum PEP Score  # Peptides Gene Symbol  condition Control      date  \
# 0               0.667           1        norV       salt     058  20240905
# 1               0.669           1        bamB       salt     058  20240905
# 2               0.674           1        uvrC       salt     058  20240905
# 3               0.676           1        paaB       salt     058  20240905
# 4               0.687           1        ampH       salt     058  20240905
# ...               ...         ...         ...        ...     ...       ...
# 196064         98.830          26        rpsA  heatshock     839  20250326
# 196065        101.665          24         rng  heatshock     839  20250326
# 196066        130.111          35        rpoC  heatshock     839  20250326
# 196067        136.401          29         prs  heatshock     839  20250326
# 196068        206.878          48        polA  heatshock     839  20250326
#
#        sample  enrichment
# 0        yadE    1.337115
# 1        yadE    0.954172
# 2        yadE    1.043993
# 3        yadE    1.161389
# 4        yadE    1.198578
# ...       ...         ...
# 196064  yagB2    1.899262
# 196065  yagB2    1.426218
# 196066  yagB2    0.691706
# 196067  yagB2    4.826310
# 196068  yagB2    8.690659
#
# [196069 rows x 8 columns]

# %% [markdown]
# ## Filter for DNA binding proteins

# %% [markdown]
# In some samples we find enrichment for proteins that are not DNA binding proteins. We use RegulonDB to get a list of all transcription factors.

# %%
from bson import decode_all

with open("../../../data/metadata/regulonDatamart.bson", "rb") as file:
    data = file.read()

# Decode all BSON documents into a list of dictionaries
documents = decode_all(data)
len(documents)
df = pd.DataFrame(documents)

name_list = []
syn_list = [] 
type_list = []

for x in df['regulator'].values:
    name_list.append(x['abbreviatedName'])
    if 'synonyms' in x.keys():
        syn_list.append(x['synonyms'])
    else:
        syn_list.append([''])
    type_list.append(x['type'])

df_TF = pd.DataFrame({"name": name_list, 'synonyms':syn_list, 'type': type_list})

# %% [markdown]
# ## Plot specific samples

# %% [markdown]
# Using the dataframe, we can make enrichment plots for specific examples shown in the paper.

# %%
def plot_mass_spec(df, sample, filter_binding_proteins=False, highlighted_genes=[], filter_control=None, yscale="log", sharey=True, filter_peptide=False):
    
    df_filtered = df[df['sample'] == sample]

    
    if filter_binding_proteins:
        # Create a set of lowercased binding protein names from df_TF
        binding_names = set(df_TF['name'].str.lower())
        binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
        
        # Filter df_filtered by checking if the lower-case gene symbol is in the set
        df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

    if filter_control != None:
        if type(filter_control) == str:
            df_filtered = df_filtered[df_filtered['Control'] == filter_control]
        elif type(filter_control) == list:
            df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

    if filter_peptide:
        df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
        

    gdf = df_filtered.groupby(['condition', 'date'])
    n_conditions = len(gdf)

    fig, ax_arr = plt.subplots(n_conditions//6 + 1, np.minimum(n_conditions, 6), figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharey=sharey)
    ax = np.ravel(ax_arr)
    #if n_conditions == 1:
        #ax = [ax]
            
    for i, ((condition, date), _df) in enumerate(gdf):
        x = np.random.randn(len(_df['enrichment']))
        ax[i].scatter(x, _df['enrichment'].values, s=12, linewidth=0)
        for gene in highlighted_genes:
            ind = np.where(_df['Gene Symbol'] == gene)
            ax[i].scatter(x[ind], _df['enrichment'].values[ind], s=12)    
        ax[i].set_yscale(yscale)
        ax[i].set_title(condition+'\n'+date)
        
        ax[i].grid(True)
        ax[i].set_ylabel("enrichment")
        
    for _ax in ax.flat:
        _ax.set_xticks([])
        _ax.label_outer()
    plt.tight_layout()

        
    return fig, ax, df_filtered.sort_values('enrichment', ascending=False)

# %%
df_combined[df_combined['sample'] == 'yqaE']
# Out:
#       Sum PEP Score  # Peptides Gene Symbol             condition Control  \
# 364           0.702           1        ispH                  salt     837
# 365           0.715           1        ynfL                  salt     837
# 366           0.721           1        leuC                  salt     837
# 367           0.726           1        ymfD                  salt     837
# 368           0.736           1        argG                  salt     837
# ...             ...         ...         ...                   ...     ...
# 8203        230.194          53        polA  stationary, high vol     837
# 8204        243.466          53        topA  stationary, high vol     837
# 8205        292.663          68        rpoC  stationary, high vol     837
# 8206        296.540          61        rpoB  stationary, high vol     837
# 8207        394.606          87        uvrA  stationary, high vol     837
#
#           date sample  enrichment
# 364   20241125   yqaE    0.894132
# 365   20241125   yqaE    1.651637
# 366   20241125   yqaE    1.167085
# 367   20241125   yqaE    1.111965
# 368   20241125   yqaE    0.620478
# ...        ...    ...         ...
# 8203  20250303   yqaE    2.313582
# 8204  20250303   yqaE    0.711905
# 8205  20250303   yqaE    1.400268
# 8206  20250303   yqaE    1.564915
# 8207  20250303   yqaE    0.834757
#
# [4445 rows x 8 columns]

# %%
np.sort(df_combined['sample'].unique())
# Out:
# array(['TSS_1414_1', 'TSS_1414_2', 'aceBp', 'acrA', 'acrZ', 'acrZ_2',
#        'araB_1', 'araB_2', 'araCp', 'araCp_2', 'blr', 'cpxR', 'cusC',
#        'cusC2', 'dicCp', 'ecnb', 'elaB', 'fldA', 'flda', 'furpb',
#        'galEp1', 'gyrA', 'icdC', 'ihfAp', 'intE', 'kbpp4', 'lacI_Oid',
#        'lpp1', 'lpp2', 'marRp', 'mglB_1', 'mglB_2', 'mhpRp2', 'ompRp2',
#        'ompRp3', 'pheMp', 'rcsBp2', 'rcsDp', 'rspA_1', 'rspA_2', 'sohA',
#        'tisB', 'tmaR_1', 'tmaR_2', 'tmaR_3', 'uofp', 'yadE', 'yadE2',
#        'yadI', 'yagB', 'yagB2', 'yahC', 'ybaY', 'ybeDp', 'ybiY1', 'ybiY2',
#        'ybiY3', 'ygiW_1', 'ygiW_2', 'yjbJ', 'yqaE', 'yqjE', 'yqjE_2',
#        'zapB1', 'zapB2', 'zapB3'], dtype=object)

# %%
df_combined[df_combined['Gene Symbol'] == 'deoR'].sort_values(by='enrichment', ascending=False).head(50)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol             condition Control  \
# 4419         48.548          12        deoR  stationary, high vol     839
# 1031         17.956           5        deoR               glucose     837
# 4419         48.548          12        deoR  stationary, high vol     837
# 7155         48.548          12        deoR  stationary, high vol     839
# 1534         23.068           6        deoR               glucose     837
# 1031         17.956           5        deoR            stationary     837
# 6243         48.548          12        deoR  stationary, high vol     839
# 1383          3.861           1        deoR             phenazine     837
# 913          22.369           6        deoR                   LB1     837
# 7155         48.548          12        deoR  stationary, high vol     837
# 456          23.068           6        deoR               glucose     837
# 2563         38.720          10        deoR            stationary     837
# 2607          3.861           1        deoR             phenazine     837
# 465          17.956           5        deoR            stationary     837
# 6231         38.720          10        deoR            stationary     837
# 4659         38.720          10        deoR            stationary     837
# 6243         48.548          12        deoR  stationary, high vol     837
# 3219          3.861           1        deoR             phenazine     837
# 2073         23.068           6        deoR               glucose     837
# 3295         17.956           5        deoR               glucose     837
# 465          17.956           5        deoR               glucose     837
# 991          38.720          10        deoR            stationary     837
# 466          24.821           6        deoR            stationary     839
# 4135         38.720          10        deoR            stationary     837
# 3087         38.720          10        deoR            stationary     837
# 1422          7.521           2        deoR            stationary     835
# 907          22.369           6        deoR                   LB2     837
# 1383          3.861           1        deoR             phenazine     839
# 4427         17.956           5        deoR               glucose     837
# 5331         48.548          12        deoR  stationary, high vol     839
# 1422          7.521           2        deoR            stationary     837
# 2729         17.956           5        deoR               glucose     837
# 6755         38.720          10        deoR            stationary     837
# 3894          7.521           2        deoR            stationary     835
# 1877         26.728           7        deoR               copper2     839
# 4306          7.521           2        deoR            stationary     835
# 2246          7.521           2        deoR            stationary     835
# 1704         34.853          13        deoR               glucose     837
# 2592         48.548          12        deoR                  salt     837
# 4993         17.956           5        deoR               glucose     837
# 1154          2.510           1        deoR                 salt2     837
# 1683         48.548          12        deoR  stationary, high vol     839
# 3894          7.521           2        deoR            stationary     837
# 4306          7.521           2        deoR            stationary     837
# 2246          7.521           2        deoR            stationary     837
# 4718          7.521           2        deoR            stationary     835
# 2607          3.861           1        deoR             phenazine     839
# 1107         28.399           8        deoR            stationary     837
# 8067         48.548          12        deoR  stationary, high vol     839
# 771          48.548          12        deoR  stationary, high vol     839
#
#           date   sample  enrichment
# 4419  20250303   ompRp2   19.777999
# 1031  20250124      blr   11.134848
# 4419  20250303   ompRp2   10.227843
# 7155  20250303   ygiW_1    9.775172
# 1534  20250113   mglB_2    8.997295
# 1031  20250124   ompRp2    8.218329
# 6243  20250303   rcsBp2    6.641546
# 1383  20250303    furpb    6.085240
# 913   20250326     yadI    5.091307
# 7155  20250303   ygiW_1    5.055058
# 456   20250113     elaB    4.481068
# 2563  20241216     gyrA    4.418534
# 2607  20250303   ompRp3    4.375896
# 465   20250124     acrA    4.037228
# 6231  20241216   ygiW_1    3.915095
# 4659  20241216   rcsBp2    3.798481
# 6243  20250303   rcsBp2    3.434558
# 3219  20250303    pheMp    3.377323
# 2073  20250113     ybaY    3.372966
# 3295  20250124    ybiY1    3.193119
# 465   20250124  araCp_2    3.085523
# 991   20241216     elaB    3.017647
# 466   20250124     yadI    2.881398
# 4135  20241216   ompRp3    2.819342
# 3087  20241216    kbpp4    2.771007
# 1422  20241125     gyrA    2.657086
# 907   20250326     yadI    2.521383
# 1383  20250303    furpb    2.423439
# 4427  20250124    ybiY3    2.382032
# 5331  20250303   ompRp3    2.379852
# 1422  20241125     gyrA    2.345475
# 2729  20250124     uofp    2.284572
# 6755  20241216   ygiW_2    2.223169
# 3894  20241125     yagB    2.199801
# 1877  20250307    cusC2    2.192929
# 4306  20241125   ygiW_1    2.177683
# 2246  20241125   rcsBp2    2.158506
# 1704  20241221   mglB_2    2.041587
# 2592  20250303     yqjE    2.033375
# 4993  20250124    zapB1    2.024739
# 1154  20241125     yjbJ    1.990664
# 1683  20250303     elaB    1.969104
# 3894  20241125     yagB    1.941819
# 4306  20241125   ygiW_1    1.922294
# 2246  20241125   rcsBp2    1.905367
# 4718  20241125   ygiW_2    1.803348
# 2607  20250303   ompRp3    1.742695
# 1107  20250213     ybaY    1.724289
# 8067  20250303     yqaE    1.706814
# 771   20250303     acrA    1.655840

# %%
import matplotlib as mpl
from matplotlib import font_manager
import os

font_path = "/Users/tomroeschinger/Library/Fonts/Lato-ThinItalic.ttf" 
if os.path.exists(font_path):
    font_manager.fontManager.addfont(font_path)
    prop = font_manager.FontProperties(fname=font_path)

weight = 'regular'
mpl.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Lato"],

    "font.weight": weight,        # ticks, text
    "axes.labelweight": weight,   # axis labels
    "axes.titleweight": weight,   # titles
})

# %%
fig, ax, df = plot_mass_spec(df_combined, 'mglB_2', filter_binding_proteins=True, highlighted_genes=['deoR'], yscale="linear", filter_control=['837'])
df.head(50)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol condition Control      date  \
# 1342          6.825           2        ulaR   glucose     837  20250113
# 1534         23.068           6        deoR   glucose     837  20250113
# 1312          3.749           1        ulaR   glucose     837  20241221
# 1362          5.148           1        yqhC   glucose     837  20241221
# 1108          1.311           1        nanR   glucose     837  20250113
# 1531         22.629           7        glpR   glucose     837  20250113
# 1480         15.238           3        stpA   glucose     837  20250113
# 1704         34.853          13        deoR   glucose     837  20241221
# 1083          0.867           1        dicA   glucose     837  20250113
# 1272          4.735           1        dksA   glucose     837  20250113
# 1462         13.433           4        rcnR   glucose     837  20250113
# 1195          3.127           1        gntR   glucose     837  20250113
# 1475          9.475           2        stpA   glucose     837  20241221
# 1454         12.914           4        ygbI   glucose     837  20250113
# 1299          3.360           1        fadR   glucose     837  20241221
# 1554         29.052          10        pepA   glucose     837  20250113
# 1458         13.333           6         lrp   glucose     837  20250113
# 1605         17.936           6        baeR   glucose     837  20241221
# 1585         16.069           8         lrp   glucose     837  20241221
# 1532         22.632           6        alaS   glucose     837  20250113
# 1359          7.454           2        xylR   glucose     837  20250113
# 1400          6.331           1        nadR   glucose     837  20241221
# 1246          1.783           1        yhaJ   glucose     837  20241221
# 1372          7.998           2        yhaJ   glucose     837  20250113
# 1194          3.107           2        fabR   glucose     837  20250113
# 1260          2.211           1        allR   glucose     837  20241221
# 1579         15.556           6         hns   glucose     837  20241221
# 1750         59.211          17        glpR   glucose     837  20241221
# 1095          1.047           1        cysB   glucose     837  20250113
# 1560         30.841          10         crp   glucose     837  20250113
# 1139          1.888           1        slyA   glucose     837  20250113
# 1482          9.934           2        iscR   glucose     837  20241221
# 1238          3.881           1         fur   glucose     837  20250113
# 1522         20.697           8        cpxR   glucose     837  20250113
# 1392          9.409           2         fnr   glucose     837  20250113
# 1416          6.919           4        araC   glucose     837  20241221
# 1571         15.002           5        arcA   glucose     837  20241221
# 1358          5.035           1        dksA   glucose     837  20241221
# 1590         16.588           4         fnr   glucose     837  20241221
# 1258          4.311           2        iscR   glucose     837  20250113
# 1085          0.890           1        trpR   glucose     837  20250113
# 1274          2.666           1        metJ   glucose     837  20241221
# 1512         11.165           4        glnG   glucose     837  20241221
# 1446         12.385           4         hns   glucose     837  20250113
# 1360          5.082           2        oxyR   glucose     837  20241221
# 1271          2.544           1        dicA   glucose     837  20241221
# 1221          1.148           1        dsdC   glucose     837  20241221
# 1238          1.621           1        cueR   glucose     837  20241221
# 1712         37.174          10         crp   glucose     837  20241221
# 1269          2.487           1        galR   glucose     837  20241221
#
#       sample  enrichment
# 1342  mglB_2   14.510417
# 1534  mglB_2    8.997295
# 1312  mglB_2    8.268668
# 1362  mglB_2    3.360749
# 1108  mglB_2    3.255756
# 1531  mglB_2    2.516760
# 1480  mglB_2    2.055439
# 1704  mglB_2    2.041587
# 1083  mglB_2    1.876405
# 1272  mglB_2    1.867375
# 1462  mglB_2    1.797953
# 1195  mglB_2    1.695688
# 1475  mglB_2    1.635175
# 1454  mglB_2    1.634718
# 1299  mglB_2    1.591096
# 1554  mglB_2    1.554140
# 1458  mglB_2    1.542001
# 1605  mglB_2    1.508369
# 1585  mglB_2    1.475649
# 1532  mglB_2    1.462631
# 1359  mglB_2    1.433601
# 1400  mglB_2    1.422906
# 1246  mglB_2    1.406261
# 1372  mglB_2    1.388136
# 1194  mglB_2    1.386859
# 1260  mglB_2    1.383550
# 1579  mglB_2    1.378023
# 1750  mglB_2    1.364407
# 1095  mglB_2    1.330811
# 1560  mglB_2    1.329730
# 1139  mglB_2    1.319697
# 1482  mglB_2    1.303746
# 1238  mglB_2    1.245966
# 1522  mglB_2    1.238548
# 1392  mglB_2    1.215131
# 1416  mglB_2    1.199750
# 1571  mglB_2    1.196184
# 1358  mglB_2    1.190909
# 1590  mglB_2    1.186954
# 1258  mglB_2    1.184730
# 1085  mglB_2    1.170815
# 1274  mglB_2    1.169623
# 1512  mglB_2    1.154825
# 1446  mglB_2    1.144559
# 1360  mglB_2    1.131625
# 1271  mglB_2    1.091666
# 1221  mglB_2    1.083559
# 1238  mglB_2    1.061986
# 1712  mglB_2    1.049308
# 1269  mglB_2    1.040603

# %%
_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(_df, 'yqaE', filter_binding_proteins=True, highlighted_genes=['cpxR'], yscale="linear")#, filter_control='839')
df.head(10)
fig.savefig("../../../figures/yqaE_mass-spec.pdf")

# %%
#_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(df_combined, 'TSS_1414_2', filter_binding_proteins=False, highlighted_genes=['ihfA', 'ihfB'], yscale="linear")#, filter_control='839')
df.head(10)
fig.savefig("../../../figures/yahM-spec.pdf")

# %%
#_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(df_combined, 'cpxR', filter_binding_proteins=False, highlighted_genes=['cpxR'], yscale="linear")#, filter_control='839')
df.head(10)
fig.savefig("../../../figures/cpxR-spec.pdf")

# %%
#_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(df_combined, 'araB_1', filter_binding_proteins=False, highlighted_genes=['araC'], yscale="linear")#, filter_control='839')
df.head(10)
fig.savefig("../../../figures/araB-spec.pdf")

# %%
#_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(df_combined, 'mglB_1', filter_binding_proteins=False, highlighted_genes=['crp'], yscale="linear")#, filter_control='839')
fig.savefig("../../../figures/mglB-spec.pdf")
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol    condition Control      date  \
# 2883         27.714           7        glgA    arabinose     839  20241221
# 1286         34.309           7        aaeR  glucose, 4C     837  20241031
# 1286         34.309           7        aaeR  glucose, 4C     839  20241031
# 1286         34.309           7        aaeR  glucose, 4C     835  20241031
# 1286         34.309           7        aaeR  glucose, 4C     058  20241031
# 1303         36.822           5        glgA  glucose, 4C     835  20241031
# 1303         36.822           5        glgA  glucose, 4C     839  20241031
# 1303         36.822           5        glgA  glucose, 4C     058  20241031
# 1383         62.104           9        ygbI  glucose, 4C     835  20241031
# 1303         36.822           5        glgA  glucose, 4C     837  20241031
#
#       sample  enrichment
# 2883  mglB_1   40.535428
# 1286  mglB_1   32.548400
# 1286  mglB_1   32.433985
# 1286  mglB_1   31.999345
# 1286  mglB_1   31.525851
# 1303  mglB_1   26.348541
# 1303  mglB_1   23.985883
# 1303  mglB_1   23.239649
# 1383  mglB_1   21.677266
# 1303  mglB_1   21.403014

# %%
#_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(df_combined, 'yadI', filter_binding_proteins=False, highlighted_genes=['crp', 'ulaR', 'csqR'], yscale="linear")#, filter_control='839')
fig.savefig("../../../figures/mglB-spec.pdf")
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol        condition Control  \
# 972           8.328           3        ulaR        salt, 37C     058
# 972           8.328           3        ulaR  stationary, 37C     058
# 659          13.091           5        csqR       stationary     837
# 3639         29.762           8        selA       stationary     835
# 882           4.914           2        csqR  stationary, 37C     058
# 674           4.674           2        ulaR              LB2     837
# 3513          9.537           4        ygaM       stationary     835
# 3513          9.537           4        ygaM       stationary     837
# 3607         21.783           7        yqjD       stationary     837
# 3592         19.474           7        elaB       stationary     837
#
#           date sample  enrichment
# 972   20240905   yadI   32.499593
# 972   20240905   yadI   31.206910
# 659   20250213   yadI   29.098970
# 3639  20241125   yadI   24.418617
# 882   20240905   yadI   19.862999
# 674   20250326   yadI   19.236358
# 3513  20241125   yadI   17.885540
# 3513  20241125   yadI   14.658921
# 3607  20241125   yadI   14.109812
# 3592  20241125   yadI   12.311270

# %%
df
# Out:
#       Sum PEP Score  # Peptides Gene Symbol  condition Control      date  \
# 1189         15.254           6        ihfB  arabinose     839  20250113
# 1036         21.826           7        ihfB  arabinose     839  20241221
# 993          16.998           5        ihfA  arabinose     839  20241221
# 1200         15.847           5        ihfA  arabinose     839  20250113
# 915           5.037           3        rlmL  arabinose     839  20250113
# ...             ...         ...         ...        ...     ...       ...
# 1355         42.784           9        priA  arabinose     839  20250113
# 1245         19.900           7        hupB  arabinose     839  20250113
# 1180         96.599          31        topA  arabinose     839  20241221
# 1193         15.504           5        deoR  arabinose     839  20250113
# 1102         34.853          13        deoR  arabinose     839  20241221
#
#           sample  enrichment
# 1189  TSS_1414_2   38.129357
# 1036  TSS_1414_2   37.353108
# 993   TSS_1414_2   30.187690
# 1200  TSS_1414_2   19.479684
# 915   TSS_1414_2    8.215804
# ...          ...         ...
# 1355  TSS_1414_2    0.232314
# 1245  TSS_1414_2    0.231278
# 1180  TSS_1414_2    0.179887
# 1193  TSS_1414_2    0.061595
# 1102  TSS_1414_2    0.040255
#
# [1314 rows x 8 columns]

# %%
df_combined[df_combined['sample'] == 'araB_2']['condition'].unique()
# Out:
# array(['glucose, 37C', 'glucose, 4C', 'arabinose'], dtype=object)

# %%
#_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(df_combined, 'araB_1', filter_binding_proteins=True, highlighted_genes=['araC'], yscale="linear")#, filter_control='839')
df.head(10)
fig.savefig("../../../figures/araB_mass-spec.pdf")

# %%
#_df = df_combined[(df_combined['condition'] == 'stationary') | (df_combined['condition'] == 'stationary, high vol')]
fig, ax, df = plot_mass_spec(df_combined, 'araB_2', filter_binding_proteins=True, highlighted_genes=['araC'], yscale="linear")#, filter_control='839')
df.head(10)
#fig.savefig("../../../figures/araB_mass-spec.pdf")
# Out:
#       Sum PEP Score  # Peptides Gene Symbol     condition Control      date  \
# 409          15.866           1         fis   glucose, 4C     058  20241031
# 409          15.866           1         fis   glucose, 4C     837  20241031
# 409          15.866           1         fis   glucose, 4C     839  20241031
# 2350          5.286           1        narP     arabinose     839  20250113
# 564          37.501          11         lrp   glucose, 4C     839  20241031
# 564          37.501          11         lrp   glucose, 4C     058  20241031
# 564          37.501          11         lrp  glucose, 37C     835  20241031
# 564          37.501          11         lrp  glucose, 37C     839  20241031
# 2545         11.760           4        cusR     arabinose     839  20250113
# 564          37.501          11         lrp  glucose, 37C     058  20241031
#
#       sample  enrichment
# 409   araB_2    8.369786
# 409   araB_2    4.213822
# 409   araB_2    3.743764
# 2350  araB_2    3.127517
# 564   araB_2    2.936791
# 564   araB_2    2.828400
# 564   araB_2    2.825722
# 564   araB_2    2.552896
# 2545  araB_2    2.486844
# 564   araB_2    2.462037

# %%
sample = 'tisB'
filter_binding_proteins=True
yscale="linear"
filter_control=['837']
highlighted_genes=['lexA']
filter_peptide=True

df_filtered = df_combined[df_combined['sample'] == sample]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

fig.savefig("../../../figures/tisB_mass-spec.pdf")

# %%
sample = 'yagB'
filter_binding_proteins=True
yscale="linear"
filter_control=None#['837']
highlighted_genes=['xynR']
filter_peptide=True

df_filtered = df_combined[df_combined['sample'] == sample]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

#fig.savefig("../../../figures/tisB_mass-spec.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 32
#      29 gdf = df_filtered.groupby(['condition', 'date'])
#      30 n_conditions = len(gdf)
# ---> 32 fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
#      33 ax = np.ravel(ax_arr)
#      34 #if n_conditions == 1:
#      35     #ax = [ax]
#
# File ~/miniforge3/envs/regseq2/lib/python3.12/site-packages/matplotlib/pyplot.py:1777, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1632 """
#    1633 Create a figure and a set of subplots.
#    1634
#    (...)   1774
#    1775 """
#    1776 fig = figure(**fig_kw)
# -> 1777 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1778                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1779                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1780                    width_ratios=width_ratios)
#    1781 return fig, axs
#
# File ~/miniforge3/envs/regseq2/lib/python3.12/site-packages/matplotlib/figure.py:918, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     914         raise ValueError("'width_ratios' must not be defined both as "
#     915                          "parameter and as key in 'gridspec_kw'")
#     916     gridspec_kw['width_ratios'] = width_ratios
# --> 918 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     919 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                   subplot_kw=subplot_kw)
#     921 return axs
#
# File ~/miniforge3/envs/regseq2/lib/python3.12/site-packages/matplotlib/figure.py:1600, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1557 """
#    1558 Low-level API for creating a `.GridSpec` that has this figure as a parent.
#    1559
#    (...)   1596
#    1597 """
#    1599 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1600 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1601 return gs
#
# File ~/miniforge3/envs/regseq2/lib/python3.12/site-packages/matplotlib/gridspec.py:363, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     360 self.hspace = hspace
#     361 self.figure = figure
# --> 363 super().__init__(nrows, ncols,
#     364                  width_ratios=width_ratios,
#     365                  height_ratios=height_ratios)
#
# File ~/miniforge3/envs/regseq2/lib/python3.12/site-packages/matplotlib/gridspec.py:48, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      33 """
#      34 Parameters
#      35 ----------
#    (...)     45     If not given, all rows will have the same height.
#      46 """
#      47 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 48     raise ValueError(
#      49         f"Number of rows must be a positive integer, not {nrows!r}")
#      50 if not isinstance(ncols, Integral) or ncols <= 0:
#      51     raise ValueError(
#      52         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not np.int64(0)

# %%
fig, ax, df = plot_mass_spec(df_combined, 'tisB', filter_binding_proteins=True, yscale="linear", filter_control=['837'], highlighted_genes=['lexA'], filter_peptide=True)

df.head(20)
fig.savefig("../../../figures/tisB_mass-spec.pdf")

# %%
for _, gdf in df.groupby('date'):
    display(gdf.head(10))
# Out:
#       Sum PEP Score  # Peptides Gene Symbol   condition Control      date  \
# 3276         63.638          12        lexA  stationary     837  20241125
# 3287        112.120          26        glgA  stationary     837  20241125
# 3195         21.783           7        yqjD  stationary     837  20241125
# 3259         50.155          16        sucB  stationary     837  20241125
# 3180         19.474           7        elaB  stationary     837  20241125
# 3292        150.649          35        glgB  stationary     837  20241125
# 3197         21.874           5         blc  stationary     837  20241125
# 3101          9.537           4        ygaM  stationary     837  20241125
# 3233         32.592          11         hns  stationary     837  20241125
# 3243         36.025           9        ybeZ  stationary     837  20241125
#
#      sample  enrichment
# 3276   tisB   57.165983
# 3287   tisB   12.297448
# 3195   tisB   12.238791
# 3259   tisB   10.216533
# 3180   tisB    9.821753
# 3292   tisB    9.771998
# 3197   tisB    9.620840
# 3101   tisB    8.378394
# 3233   tisB    7.654899
# 3243   tisB    6.837286
#       Sum PEP Score  # Peptides Gene Symbol   condition Control      date  \
# 5693         34.079          11        lexA  stationary     837  20241216
# 5576         13.162           3        stpA  stationary     837  20241216
# 5680         30.018          10         hns  stationary     837  20241216
# 5760        170.112          40         prs  stationary     837  20241216
# 5588         14.743           4        cobB  stationary     837  20241216
# 5610         16.581           5        aaeR  stationary     837  20241216
# 5546         10.384           3        xseB  stationary     837  20241216
# 5674         27.605           7        bluR  stationary     837  20241216
# 5747         82.637          21        glgA  stationary     837  20241216
# 5565         11.975           4        ihfA  stationary     837  20241216
#
#      sample  enrichment
# 5693   tisB   25.775129
# 5576   tisB   25.268218
# 5680   tisB   23.826317
# 5760   tisB   21.336730
# 5588   tisB    8.214874
# 5610   tisB    7.687860
# 5546   tisB    7.340295
# 5674   tisB    7.321778
# 5747   tisB    6.314378
# 5565   tisB    4.661609
#       Sum PEP Score  # Peptides Gene Symbol condition Control      date  \
# 1326        111.487          28        sucB      H2O2     837  20250307
# 1247         34.744           9        stpA      H2O2     837  20250307
# 1290         47.203           9         prs      H2O2     837  20250307
# 1035          9.452           3         pta      H2O2     837  20250307
# 996           7.839           4         hns      H2O2     837  20250307
# 1328        114.261          26        lpdA      H2O2     837  20250307
# 1067         11.379           3        lexA      H2O2     837  20250307
# 1309         59.942          16        sucA      H2O2     837  20250307
# 1263         38.676          11         lrp      H2O2     837  20250307
# 1098         13.108           4        fabR      H2O2     837  20250307
#
#      sample  enrichment
# 1326   tisB   19.832990
# 1247   tisB   13.402358
# 1290   tisB   10.884659
# 1035   tisB    9.134442
# 996    tisB    8.711427
# 1328   tisB    7.146761
# 1067   tisB    4.992259
# 1309   tisB    4.241681
# 1263   tisB    4.196226
# 1098   tisB    3.419206
#      Sum PEP Score  # Peptides Gene Symbol condition Control      date sample  \
# 973         58.443          20        sucB      H2O2     837  20250326   tisB
# 914         22.648           6        cobB      H2O2     837  20250326   tisB
# 990        136.401          29         prs      H2O2     837  20250326   tisB
# 852         13.097           4        sfsA      H2O2     837  20250326   tisB
# 724          5.856           4         hns      H2O2     837  20250326   tisB
# 550          1.652           2        yciY      H2O2     837  20250326   tisB
# 872         15.236           4        stpA      H2O2     837  20250326   tisB
# 837         12.017           6        sucA      H2O2     837  20250326   tisB
# 966         48.159          12        lpdA      H2O2     837  20250326   tisB
# 744          6.758           2        galF      H2O2     837  20250326   tisB
#
#      enrichment
# 973   32.067407
# 914   13.881923
# 990   12.346792
# 852    8.927396
# 724    8.440639
# 550    7.584626
# 872    6.500875
# 837    4.757470
# 966    4.217076
# 744    4.089607

# %%
df_combined[df_combined['sample'] == 'yqaE']
# Out:
#       Sum PEP Score  # Peptides Gene Symbol             condition Control  \
# 364           0.702           1        ispH                  salt     837
# 365           0.715           1        ynfL                  salt     837
# 366           0.721           1        leuC                  salt     837
# 367           0.726           1        ymfD                  salt     837
# 368           0.736           1        argG                  salt     837
# ...             ...         ...         ...                   ...     ...
# 8203        230.194          53        polA  stationary, high vol     837
# 8204        243.466          53        topA  stationary, high vol     837
# 8205        292.663          68        rpoC  stationary, high vol     837
# 8206        296.540          61        rpoB  stationary, high vol     837
# 8207        394.606          87        uvrA  stationary, high vol     837
#
#           date sample  enrichment
# 364   20241125   yqaE    0.894132
# 365   20241125   yqaE    1.651637
# 366   20241125   yqaE    1.167085
# 367   20241125   yqaE    1.111965
# 368   20241125   yqaE    0.620478
# ...        ...    ...         ...
# 8203  20250303   yqaE    2.313582
# 8204  20250303   yqaE    0.711905
# 8205  20250303   yqaE    1.400268
# 8206  20250303   yqaE    1.564915
# 8207  20250303   yqaE    0.834757
#
# [4445 rows x 8 columns]

# %%
fig, ax, df = plot_mass_spec(df_combined, 'cpxR', filter_binding_proteins=True, highlighted_genes=['cpxR'], filter_control='839', yscale="linear")
fig.savefig("../../../figures/cpxR_mass-spec.pdf")
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol   condition Control      date  \
# 969          20.697           8        cpxR  gentamicin     839  20250113
# 1007         22.651           5        cpxR  gentamicin     839  20250124
# 516          23.274           6        cpxR     copper1     839  20250307
# 516          23.274           6        cpxR     copper2     839  20250307
# 887          11.306           4        fabR  gentamicin     839  20250124
# 586           1.438           1        narP  gentamicin     839  20250124
# 265           5.906           3        accB     copper1     839  20250307
# 101           2.494           1        nrdR     copper2     839  20250307
# 428          13.108           4        fabR     copper2     839  20250307
# 654           3.255           2        glnG  gentamicin     839  20250113
#
#      sample  enrichment
# 969    cpxR   76.862169
# 1007   cpxR   31.857194
# 516    cpxR   18.793393
# 516    cpxR   11.147950
# 887    cpxR    7.666107
# 586    cpxR    4.846569
# 265    cpxR    3.218248
# 101    cpxR    2.565797
# 428    cpxR    2.325626
# 654    cpxR    2.298107

# %%
sample = 'cpxR'
filter_binding_proteins=True
yscale="linear"
filter_control=['839']
highlighted_genes=['cpxR']
filter_peptide=True

df_filtered = df_combined[df_combined['sample'] == sample]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(2, 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

fig.savefig("../../../figures/cpxR_mass-spec.pdf")

# %%
sample = 'yqaE'
filter_binding_proteins=True
yscale="linear"
filter_control=['837']
highlighted_genes=['cpxR']
filter_peptide=True

df_filtered = df_combined[df_combined['sample'] == sample]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

#fig.savefig("../../../figures/yqaE_mass-spec.pdf")

# %%
sample = 'acrZ'
#filter_binding_proteins=True
yscale="linear"
filter_control=['839']
highlighted_genes=['rob']
filter_peptide=False

df_filtered = df_combined[df_combined['sample'] == sample]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

fig.savefig("../../../figures/arcZ_mass-spec.pdf")

# %%
fig, ax_arr = plt.subplots(2, 3, figsize=(5, 1), sharex='col')
ax = np.ravel(ax_arr)
j=0
for sample in ['ybiY1', 'ybiY2', 'ybiY3']:
    #filter_binding_proteins=True
    yscale="linear"
    filter_control=None#[]
    highlighted_genes=['yciT']
    filter_peptide=False
    filter_binding_proteins=True
    df_filtered = df_combined[df_combined['sample'] == sample]


    if filter_binding_proteins:
        # Create a set of lowercased binding protein names from df_TF
        binding_names = set(df_TF['name'].str.lower())
        binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
        
        # Filter df_filtered by checking if the lower-case gene symbol is in the set
        df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

    if filter_control != None:
        if type(filter_control) == str:
            df_filtered = df_filtered[df_filtered['Control'] == filter_control]
        elif type(filter_control) == list:
            df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

    if filter_peptide:
        df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
        

    gdf = df_filtered.groupby(['condition', 'date'])
    n_conditions = len(gdf)


    #if n_conditions == 1:
        #ax = [ax]
            
    for i, ((condition, date), _df) in enumerate(gdf):
        x = np.random.randn(len(_df['enrichment']))
        ax_arr[i, j].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
        for gene in highlighted_genes:
            ind = np.where(_df['Gene Symbol'] == gene)
            ax_arr[i, j].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
        #ax[i].set_yscale(yscale)
        ax_arr[i, j].set_title(condition+'\n'+date)
        
        ax_arr[i, j].grid(True)
        ax_arr[i, j].set_xlabel("enrichment")
    j += 1
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()
    _ax.set_ylim(-3, 3)

fig.savefig("../../../figures/ybiY_mass-spec.pdf")

# %%
sample = 'ybiY2'
#filter_binding_proteins=True
yscale="linear"
filter_control=None#[]
highlighted_genes=['yciT']
filter_peptide=False
filter_binding_proteins=True
df_filtered = df_combined[df_combined['sample'] == sample]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

#fig.savefig("../../../figures/arcZ_mass-spec.pdf")

# %%
sample = 'ybiY3'
#filter_binding_proteins=True
yscale="linear"
filter_control=None#[]
highlighted_genes=['yciT']
filter_peptide=False
filter_binding_proteins=True
df_filtered = df_combined[df_combined['sample'] == sample]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

#fig.savefig("../../../figures/arcZ_mass-spec.pdf")

# %%
df_filtered.sort_values(by='enrichment')
# Out:
#      Sum PEP Score  # Peptides Gene Symbol   condition Control      date  \
# 468         38.720          10        deoR  stationary     839  20241216
# 771          3.861           1        deoR   dipyridyl     839  20250303
# 339         28.231           6        nagC  stationary     839  20241125
# 434         56.560          15        deoR   dipyridyl     837  20241216
# 434         56.560          15        deoR   dipyridyl     839  20241216
# ..             ...         ...         ...         ...     ...       ...
# 401         31.610          10         hns   dipyridyl     839  20241216
# 40           1.319           1         rob   dipyridyl     839  20241216
# 155          4.101           2         rob  stationary     839  20241216
# 40           1.319           1         rob   dipyridyl     837  20241216
# 563          2.554           1         rob   dipyridyl     839  20241221
#
#     sample  enrichment
# 468   acrZ    0.072775
# 771   acrZ    0.074972
# 339   acrZ    0.076056
# 434   acrZ    0.091179
# 434   acrZ    0.100417
# ..     ...         ...
# 401   acrZ    5.126547
# 40    acrZ   28.076300
# 155   acrZ   29.534154
# 40    acrZ   38.675641
# 563   acrZ   44.721039
#
# [451 rows x 8 columns]

# %%
fig, ax, df = plot_mass_spec(df_combined, 'yadI', filter_binding_proteins=True, yscale="linear")#, filter_control=['839', '058'], highlighted_genes=['lrp', 'yhaJ'])
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol        condition Control  \
# 972           8.328           3        ulaR        salt, 37C     058
# 972           8.328           3        ulaR  stationary, 37C     058
# 659          13.091           5        csqR       stationary     837
# 882           4.914           2        csqR  stationary, 37C     058
# 674           4.674           2        ulaR              LB2     837
# 882           4.914           2        csqR        salt, 37C     058
# 1178         30.242          11         lrp        salt, 37C     058
# 3370          3.079           1        ulaR       stationary     835
# 679           4.674           2        ulaR              LB1     837
# 530           4.466           2        ulaR       stationary     837
#
#           date sample  enrichment
# 972   20240905   yadI   32.499593
# 972   20240905   yadI   31.206910
# 659   20250213   yadI   29.098970
# 882   20240905   yadI   19.862999
# 674   20250326   yadI   19.236358
# 882   20240905   yadI   11.236348
# 1178  20240905   yadI    9.324024
# 3370  20241125   yadI    8.336464
# 679   20250326   yadI    7.864015
# 530   20250213   yadI    7.381577

# %%
fig, ax, df = plot_mass_spec(df_combined, 'ygiW_2', filter_binding_proteins=True, yscale="linear", filter_control=['839'], highlighted_genes=['tyrR'])
fig.savefig("../../../figures/ygiW_2_mass-spec.pdf")
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol   condition Control      date  \
# 4711          7.082           2        tyrR  stationary     839  20241125
# 6492          5.002           3        tyrR  stationary     839  20241216
# 6748         31.993          10        glpR  stationary     839  20241216
# 6706         20.868          12         lrp  stationary     839  20241216
# 4906         46.998          12        glpR  stationary     839  20241125
# 4683          5.593           1        frlR  stationary     839  20241125
# 4613          3.231           2        agaR  stationary     839  20241125
# 6603         10.021           4        cytR  stationary     839  20241216
# 6574          8.820           2        argP  stationary     839  20241216
# 6425          3.415           1        nikR  stationary     839  20241216
#
#       sample  enrichment
# 4711  ygiW_2   44.976047
# 6492  ygiW_2   22.127394
# 6748  ygiW_2    4.567839
# 6706  ygiW_2    3.151348
# 4906  ygiW_2    2.920084
# 4683  ygiW_2    2.875151
# 4613  ygiW_2    2.601370
# 6603  ygiW_2    2.383413
# 6574  ygiW_2    2.352815
# 6425  ygiW_2    2.160557

# %%
fig, ax, df = plot_mass_spec(df_combined, 'ybiY1', filter_binding_proteins=True, yscale="linear", highlighted_genes=['yciT'])#, filter_control=['837'], highlighted_genes=['yciT'])
fig.savefig("../../../figures/ybiY1_mass-spec.pdf")
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol condition Control      date  \
# 4099         18.759           4        yciT   glucose     839  20250213
# 3300         19.279           7        yciT   glucose     837  20250124
# 3248         12.508           4        glpR   glucose     837  20250124
# 3956          6.725           2        glpR   glucose     839  20250213
# 3035          4.810           2         fnr   glucose     837  20250124
# 4074         14.848           6         lrp   glucose     839  20250213
# 3295         17.956           5        deoR   glucose     837  20250124
# 3324         25.433           8        nagC   glucose     837  20250124
# 4123         22.252           6        glnG   glucose     839  20250213
# 3012          4.395           3        fabR   glucose     837  20250124
#
#      sample  enrichment
# 4099  ybiY1  105.648018
# 3300  ybiY1   95.786780
# 3248  ybiY1   15.257256
# 3956  ybiY1    3.355517
# 3035  ybiY1    3.289517
# 4074  ybiY1    3.241445
# 3295  ybiY1    3.193119
# 3324  ybiY1    2.925450
# 4123  ybiY1    2.624442
# 3012  ybiY1    2.442240

# %%
fig, ax, df = plot_mass_spec(df_combined, 'intE', filter_binding_proteins=True, yscale="linear", highlighted_genes=['yhaJ'])#, filter_control=['837'], highlighted_genes=['yciT'])

fig.savefig("../../../figures/intE_mass-spec.pdf")
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol   condition Control      date  \
# 1470         13.014           4        yhaJ  gentamicin     839  20250124
# 1352          7.998           2        yhaJ  gentamicin     839  20250113
# 1477         13.577           1        nadR  gentamicin     839  20250124
# 1186          3.255           2        glnG  gentamicin     839  20250113
# 1510         22.629           7        glpR  gentamicin     839  20250113
# 1319          5.820           1        baeR  gentamicin     839  20250124
# 1584         27.360           8        glpR  gentamicin     839  20250124
# 1561         22.841           8         crp  gentamicin     839  20250124
# 1069          0.867           1        dicA  gentamicin     839  20250113
# 1372          9.409           2         fnr  gentamicin     839  20250113
#
#      sample  enrichment
# 1470   intE   33.451991
# 1352   intE   15.571426
# 1477   intE    4.790699
# 1186   intE    3.448022
# 1510   intE    3.378614
# 1319   intE    2.435948
# 1584   intE    2.309787
# 1561   intE    2.227766
# 1069   intE    2.080970
# 1372   intE    1.785811

# %%
fig, ax, df = plot_mass_spec(df_combined[(df_combined['condition'] == 'stationary, 37C') & ((df_combined['date'] == '20241105') | (df_combined['date'] == '20241031'))], 'yagB', filter_binding_proteins=True, yscale="linear", highlighted_genes=['xynR'])#, filter_control=['837'], sharey=True)
fig.savefig("../../../figures/yagB_mass-spec.pdf")
df.head(10)
# Out:
#      Sum PEP Score  # Peptides Gene Symbol        condition Control      date  \
# 604         42.200          11        xynR  stationary, 37C     058  20241105
# 604         42.200          11        xynR  stationary, 37C     058  20241031
# 274          8.465           1        cusR  stationary, 37C     058  20241031
# 274          8.465           1        cusR  stationary, 37C     058  20241105
# 732        110.886          15         lrp  stationary, 37C     058  20241105
# 732        110.886          15         lrp  stationary, 37C     058  20241031
# 313          9.992           3        yhaJ  stationary, 37C     058  20241105
# 313          9.992           3        yhaJ  stationary, 37C     058  20241031
# 263          8.075           2         fur  stationary, 37C     058  20241031
# 263          8.075           2         fur  stationary, 37C     058  20241105
#
#     sample  enrichment
# 604   yagB    5.570084
# 604   yagB    5.570084
# 274   yagB    1.874902
# 274   yagB    1.874902
# 732   yagB    1.491303
# 732   yagB    1.491303
# 313   yagB    1.436733
# 313   yagB    1.436733
# 263   yagB    1.392765
# 263   yagB    1.392765

# %%
df_combined[df_combined['condition'] == 'stationary, 37C']
# Out:
#       Sum PEP Score  # Peptides Gene Symbol        condition Control  \
# 0             0.857           1        dkgA  stationary, 37C     058
# 1             0.862           1        yfcS  stationary, 37C     058
# 2             0.885           1       coaBC  stationary, 37C     058
# 3             0.885           1        fucU  stationary, 37C     058
# 4             0.888           1        yeeJ  stationary, 37C     058
# ...             ...         ...         ...              ...     ...
# 1531        338.773          57        rpoC  stationary, 37C     058
# 1532        342.687          45        adhE  stationary, 37C     058
# 1533        358.035          61        aceE  stationary, 37C     058
# 1534        440.863          49        polA  stationary, 37C     058
# 1535        819.511         122         ALB  stationary, 37C     058
#
#           date sample  enrichment
# 0     20240905   yadE    5.194367
# 1     20240905   yadE    0.481782
# 2     20240905   yadE    0.407128
# 3     20240905   yadE    0.635106
# 4     20240905   yadE    0.836565
# ...        ...    ...         ...
# 1531  20241105   yjbJ    1.060139
# 1532  20241105   yjbJ    1.052733
# 1533  20241105   yjbJ    1.564338
# 1534  20241105   yjbJ    1.348861
# 1535  20241105   yjbJ    0.908420
#
# [6834 rows x 8 columns]

# %%
fig, ax, df = plot_mass_spec(df_combined, 'yagB', filter_binding_proteins=True, yscale="linear", highlighted_genes=['xynR'])#, filter_control=['837'], sharey=True)
fig.savefig("../../../figures/yagB_mass-spec.pdf")
df.head(10)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol        condition Control  \
# 1782         23.703           9        xynR  stationary, 37C     058
# 4064         35.123           8        xynR       stationary     835
# 1304          1.603           1         fis        salt, 37C     058
# 1782         23.703           9        xynR        salt, 37C     058
# 669          61.464          11         hns   stationary, 4C     058
# 669          61.464          11         hns       stationary     058
# 4064         35.123           8        xynR       stationary     837
# 4064         35.123           8        xynR       stationary     839
# 1805         30.242          11         lrp        salt, 37C     058
# 434          26.715          10        glpR        heatshock     839
#
#           date sample  enrichment
# 1782  20240905   yagB   52.626764
# 4064  20241125   yagB   39.992715
# 1304  20240905   yagB   39.533248
# 1782  20240905   yagB   37.349865
# 669   20241105   yagB   36.052392
# 669   20241031   yagB   36.052392
# 4064  20241125   yagB   34.194995
# 4064  20241125   yagB   32.467308
# 1805  20240905   yagB   17.800369
# 434   20250326   yagB   17.748931

# %%
sample = 'yagB'
#filter_binding_proteins=True
yscale="linear"
filter_control=['837', '058']
highlighted_genes=['xynR']
filter_peptide=True
filter_binding_proteins=True
df_filtered = df_combined[(df_combined['sample'] == sample) & (df_combined['condition'] == 'stationary')]


if filter_binding_proteins:
    # Create a set of lowercased binding protein names from df_TF
    binding_names = set(df_TF['name'].str.lower())
    binding_names |= {syn.lower() for synonyms in df_TF['synonyms'] for syn in synonyms}
    
    # Filter df_filtered by checking if the lower-case gene symbol is in the set
    df_filtered = df_filtered[df_filtered['Gene Symbol'].str.lower().isin(binding_names)]

if filter_control != None:
    if type(filter_control) == str:
        df_filtered = df_filtered[df_filtered['Control'] == filter_control]
    elif type(filter_control) == list:
        df_filtered = df_filtered[[y in filter_control for y in df_filtered['Control']]]

if filter_peptide:
    df_filtered = df_filtered[df_filtered["# Peptides"] > 1]
    

gdf = df_filtered.groupby(['condition', 'date'])
n_conditions = len(gdf)

fig, ax_arr = plt.subplots(np.minimum(n_conditions, 6), n_conditions//6 + 1, figsize=(np.minimum(n_conditions, 6), 2 * (n_conditions//6 + 1)), sharex=True)
ax = np.ravel(ax_arr)
#if n_conditions == 1:
    #ax = [ax]
        
for i, ((condition, date), _df) in enumerate(gdf):
    x = np.random.randn(len(_df['enrichment']))
    ax[i].scatter(_df['enrichment'].values, x, s=12, linewidth=0)
    for gene in highlighted_genes:
        ind = np.where(_df['Gene Symbol'] == gene)
        ax[i].scatter(_df['enrichment'].values[ind], x[ind], s=12)    
    #ax[i].set_yscale(yscale)
    ax[i].set_title(condition+'\n'+date)
    
    ax[i].grid(True)
    ax[i].set_xlabel("enrichment")
    
for _ax in ax.flat:
    _ax.set_yticks([])
    _ax.label_outer()

fig.savefig("../../../figures/yagB_mass-spec.pdf")

# %%
df_filtered.sort_values(by='enrichment', ascending=False)
# Out:
#       Sum PEP Score  # Peptides Gene Symbol   condition Control      date  \
# 669          61.464          11         hns  stationary     058  20241031
# 4064         35.123           8        xynR  stationary     837  20241125
# 604          42.200          11        xynR  stationary     058  20241031
# 4057         32.592          11         hns  stationary     837  20241125
# 476          21.812           5        bluR  stationary     058  20241031
# ...             ...         ...         ...         ...     ...       ...
# 4071         37.749          10        accB  stationary     837  20241125
# 660          59.292          11        ygbI  stationary     058  20241031
# 3961         13.132           3        frmR  stationary     837  20241125
# 408          15.874           3        murR  stationary     058  20241031
# 685          72.612          13        deoR  stationary     058  20241031
#
#      sample  enrichment
# 669    yagB   36.052392
# 4064   yagB   34.194995
# 604    yagB   11.684809
# 4057   yagB    9.537185
# 476    yagB    8.343814
# ...     ...         ...
# 4071   yagB    0.386993
# 660    yagB    0.310038
# 3961   yagB    0.285367
# 408    yagB    0.277227
# 685    yagB    0.263829
#
# [142 rows x 8 columns]
